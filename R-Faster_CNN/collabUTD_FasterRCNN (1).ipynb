# %%
# Going to use TrashCAN 1.0 Dataset (https://conservancy.umn.edu/handle/11299/214865)https://arxiv.org/pdf/2007.08097.pdf
# Specifically, use TrashCAN-Material sub-dataset with the following classes:

'''
 'rov': 0,
 'plant': 1,
 'animal_fish': 2,
 'animal_starfish': 3,
 'animal_shells': 4,
 'animal_crab': 5,
 'animal_eel': 6,
 'animal_etc': 7,
 'trash_etc': 8,
 'trash_fabric': 9,
 'trash_fishing_gear': 10,
 'trash_metal': 11,
 'trash_paper': 12,
 'trash_plastic': 13,
 'trash_rubber': 14,
 'trash_wood': 15
'''

# This dataset includes both detection and segmentation labels (going to just focus on detection)
# Out:
# "\n 'rov': 0,\n 'plant': 1,\n 'animal_fish': 2,\n 'animal_starfish': 3,\n 'animal_shells': 4,\n 'animal_crab': 5,\n 'animal_eel': 6,\n 'animal_etc': 7,\n 'trash_etc': 8,\n 'trash_fabric': 9,\n 'trash_fishing_gear': 10,\n 'trash_metal': 11,\n 'trash_paper': 12,\n 'trash_plastic': 13,\n 'trash_rubber': 14,\n 'trash_wood': 15\n"

# %% [markdown]
# ##**Setup of Environment and Datasets**

# %%
# for debugging
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
import json
from PIL import Image
from PIL import ImageDraw
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
import pycocotools
import numpy as np
import copy
import math
# !pip3 install pickle5
import pickle5 as pickle
import matplotlib.pyplot as plt

# pickle compatibility:
# because lower pandas version used in colab, make sure pickle files are protocol = 4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pickle5
#   Downloading pickle5-0.0.12-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (256 kB)
#      |████████████████████████████████| 256 kB 7.1 MB/s
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.12

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/MyDrive')

# %%
# define the torchvision image transforms
# here just the basic transform which converts an input image to a tensor
# later, can include data augmentation here, like transforms.RandomHorizontalFlip(0.5) (just add to the list)
# note that data augmentation will only be performed on training data

transform = transforms.Compose([
    transforms.ToTensor(),
])

# %%
# construct Dataset class for pytorch

class UnderwaterTrashDataset(torch.utils.data.Dataset):
    '''
    Pytorch Dataset class for Underwater Trash Dataset (Trash_CAN 1.0)
    
    data_file_path := path to pickle file containing dataset (annotations and filenames to images)
    images_path := path to folder containing actual image files
    transforms := data transformation and augmentation
    '''
    
    def __init__(self, data_file_path, images_path, transforms=None):
        #if data_file_path:
            #self.data = pickle.loads(data_file_path)
            #self.classes = self.data.category_id.unique()
        with open(data_file_path, 'rb') as pickle_file:
            self.data = pickle.load(pickle_file)
            self.classes = self.data.category_id.unique()
        self.images_path = images_path
        self.transforms = transforms
    
    
    def __getitem__(self, idx):
        temp = self.data[self.data.image_id == idx]
        
        image = Image.open(os.path.join(self.images_path, temp.file_name.iloc[0])).convert("RGB")
        
        box_list = copy.deepcopy(list(temp.bbox))

        for box in box_list: # xmax = xmin + width, ymax = ymin + height
            box[2] = box[2] + box[0]
            box[3] = box[3] + box[1]
        
        box_list = torch.as_tensor(box_list, dtype=torch.float32)
        
        labels = torch.as_tensor(temp.category_id.values - 1, dtype=torch.int64)
        # labels = torch.as_tensor(temp.category_id.values, dtype=torch.int64)
        
        image_id = torch.tensor([idx])
        
        area = (box_list[:, 3] - box_list[:, 1]) * (box_list[:, 2] - box_list[:,0])
        
        iscrowd = torch.zeros((len(box_list),), dtype=torch.int64)
        
        target = {}
        target["boxes"] = box_list
        target["labels"] = labels
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd
        
        if self.transforms:
            image = self.transforms(image)
            
        return image, target

    
    def __len__(self):
        return self.data.image_id.nunique()

# %%
#!pip install --upgrade pandas

pd.__version__
# Out:
# '1.3.5'

# %%
# instantiate datasets

train = UnderwaterTrashDataset('/content/drive/MyDrive/UTD_train.pkl', '/content/drive/MyDrive/train', transforms=transform)
val = UnderwaterTrashDataset('/content/drive/MyDrive/UTD_val.pkl', '/content/drive/MyDrive/val', transforms=transform)
test = UnderwaterTrashDataset('/content/drive/MyDrive/UTD_test.pkl', '/content/drive/MyDrive/UTD/material_version/test/', transforms=transform)

# %%
train[1]
# Out:
# (tensor([[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0118, 0.0118, 0.0118,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0157, 0.0157, 0.0157,  ..., 0.0157, 0.0157, 0.0157],
#           [0.0235, 0.0235, 0.0235,  ..., 0.0314, 0.0314, 0.0314]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]]),
#  {'boxes': tensor([[  1.0020, 171.0020, 477.9980, 316.9980],
#           [233.0083, 252.0040, 271.9950, 282.9960],
#           [270.0312, 246.0034, 309.9933, 275.9933],
#           [  5.0045, 238.0041,  39.9839, 263.9688]]),
#   'labels': tensor([1, 3, 3, 3]),
#   'image_id': tensor([1]),
#   'area': tensor([69639.5625,  1208.2725,  1198.4541,   908.2279]),
#   'iscrowd': tensor([0, 0, 0, 0])})

# %%
def collate_fn(batch):
    return tuple(zip(*batch))

# %%
# loads in the model and adjusts the last layer to output the correct number of classes
# change this later

def get_model(num_classes):
   # load an object detection model pre-trained on COCO
   model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)

   # get the number of input features for the classifier
   in_features = model.roi_heads.box_predictor.cls_score.in_features

   # replace the pre-trained head with a new one
   model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
   
   return model

# %%
# need to copy training reference file from torch repo:
# os.mkdir('/content/gdrive/MyDrive/torch_training_ref')
os.chdir('/content/drive/MyDrive/')

# %%
# %%bash
# git clone https://github.com/pytorch/vision.git
# cd vision
# cp references/detection/utils.py ../
# cp references/detection/transforms.py ../
# cp references/detection/coco_eval.py ../
# cp references/detection/engine.py ../
# cp references/detection/coco_utils.py ../
# Out:
# Cloning into 'vision'...
# Checking out files: 100% (860/860), done.

# %%
# define training and validation data loaders
data_loader_train = torch.utils.data.DataLoader(train, batch_size=8, 
                                                shuffle=True, num_workers=2,
                                                collate_fn=collate_fn)

data_loader_val = torch.utils.data.DataLoader(val, batch_size=8,
                                              shuffle=False, num_workers=2,
                                              collate_fn=collate_fn)

# %% [markdown]
# ##**Training**

# %%
torch.cuda.is_available() # check GPU availability
# Out:
# False

# %%
# change these hyperparams later

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# our dataset has 16 classes (see list above)
num_classes = 16

# get the model using our helper function
model = get_model(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.002,
                            momentum=0.9, weight_decay=0.0001)

# and a learning rate scheduler which decreases the learning rate by # 10x every 3 epochs
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

# %%
val_losses = []
train_losses = []

# %%
from engine import train_one_epoch, evaluate

# let's train it for 10 epochs
num_epochs = 4

for epoch in range(num_epochs):
   # train for one epoch, printing every 10 iterations
   train_one_epoch(model, optimizer, data_loader_train, device, epoch, print_freq=10)
   #train_losses.append(loss_train.item())
   # update the learning rate
   lr_scheduler.step()
   # evaluate on the test dataset
   evaluate(model, data_loader_val, device=device)
# Out:
# Epoch: [0]  [  0/751]  eta: 0:32:02  lr: 0.000005  loss: 0.2033 (0.2033)  loss_classifier: 0.1146 (0.1146)  loss_box_reg: 0.0767 (0.0767)  loss_objectness: 0.0055 (0.0055)  loss_rpn_box_reg: 0.0065 (0.0065)  time: 2.5600  data: 0.2612  max mem: 11382
# Epoch: [0]  [ 10/751]  eta: 0:28:17  lr: 0.000031  loss: 0.2033 (0.2195)  loss_classifier: 0.1146 (0.1133)  loss_box_reg: 0.0913 (0.0880)  loss_objectness: 0.0056 (0.0078)  loss_rpn_box_reg: 0.0080 (0.0105)  time: 2.2906  data: 0.0478  max mem: 11382
# Epoch: [0]  [ 20/751]  eta: 0:28:00  lr: 0.000058  loss: 0.2207 (0.2276)  loss_classifier: 0.1214 (0.1205)  loss_box_reg: 0.0913 (0.0914)  loss_objectness: 0.0055 (0.0067)  loss_rpn_box_reg: 0.0078 (0.0091)  time: 2.2856  data: 0.0261  max mem: 11382
# Epoch: [0]  [ 30/751]  eta: 0:27:48  lr: 0.000085  loss: 0.2208 (0.2238)  loss_classifier: 0.1214 (0.1199)  loss_box_reg: 0.0858 (0.0888)  loss_objectness: 0.0052 (0.0062)  loss_rpn_box_reg: 0.0064 (0.0090)  time: 2.3270  data: 0.0263  max mem: 11382
# Epoch: [0]  [ 40/751]  eta: 0:27:36  lr: 0.000111  loss: 0.2208 (0.2240)  loss_classifier: 0.1148 (0.1187)  loss_box_reg: 0.0848 (0.0899)  loss_objectness: 0.0058 (0.0065)  loss_rpn_box_reg: 0.0069 (0.0088)  time: 2.3632  data: 0.0260  max mem: 11382
# Epoch: [0]  [ 50/751]  eta: 0:27:25  lr: 0.000138  loss: 0.2302 (0.2290)  loss_classifier: 0.1083 (0.1213)  loss_box_reg: 0.0915 (0.0919)  loss_objectness: 0.0049 (0.0063)  loss_rpn_box_reg: 0.0069 (0.0095)  time: 2.3977  data: 0.0258  max mem: 11382
# Epoch: [0]  [ 60/751]  eta: 0:27:09  lr: 0.000165  loss: 0.2072 (0.2246)  loss_classifier: 0.1095 (0.1190)  loss_box_reg: 0.0831 (0.0902)  loss_objectness: 0.0045 (0.0061)  loss_rpn_box_reg: 0.0064 (0.0094)  time: 2.4159  data: 0.0270  max mem: 11382
# Epoch: [0]  [ 70/751]  eta: 0:26:54  lr: 0.000191  loss: 0.1965 (0.2242)  loss_classifier: 0.1038 (0.1184)  loss_box_reg: 0.0747 (0.0894)  loss_objectness: 0.0060 (0.0064)  loss_rpn_box_reg: 0.0071 (0.0100)  time: 2.4322  data: 0.0268  max mem: 11382
# Epoch: [0]  [ 80/751]  eta: 0:26:39  lr: 0.000218  loss: 0.2011 (0.2253)  loss_classifier: 0.0947 (0.1186)  loss_box_reg: 0.0809 (0.0903)  loss_objectness: 0.0060 (0.0063)  loss_rpn_box_reg: 0.0092 (0.0101)  time: 2.4600  data: 0.0267  max mem: 11382
# Epoch: [0]  [ 90/751]  eta: 0:26:22  lr: 0.000244  loss: 0.2080 (0.2258)  loss_classifier: 0.0914 (0.1189)  loss_box_reg: 0.0915 (0.0909)  loss_objectness: 0.0046 (0.0062)  loss_rpn_box_reg: 0.0076 (0.0098)  time: 2.4767  data: 0.0273  max mem: 11382
# Epoch: [0]  [100/751]  eta: 0:26:05  lr: 0.000271  loss: 0.1961 (0.2285)  loss_classifier: 0.1032 (0.1204)  loss_box_reg: 0.0807 (0.0923)  loss_objectness: 0.0048 (0.0062)  loss_rpn_box_reg: 0.0067 (0.0097)  time: 2.4886  data: 0.0268  max mem: 11382
# Epoch: [0]  [110/751]  eta: 0:25:46  lr: 0.000298  loss: 0.1961 (0.2264)  loss_classifier: 0.1032 (0.1190)  loss_box_reg: 0.0786 (0.0913)  loss_objectness: 0.0051 (0.0064)  loss_rpn_box_reg: 0.0067 (0.0097)  time: 2.5002  data: 0.0263  max mem: 11382
# Epoch: [0]  [120/751]  eta: 0:25:28  lr: 0.000324  loss: 0.2089 (0.2293)  loss_classifier: 0.1088 (0.1201)  loss_box_reg: 0.0839 (0.0922)  loss_objectness: 0.0066 (0.0065)  loss_rpn_box_reg: 0.0096 (0.0105)  time: 2.5132  data: 0.0270  max mem: 11382
# Epoch: [0]  [130/751]  eta: 0:25:08  lr: 0.000351  loss: 0.2445 (0.2342)  loss_classifier: 0.1289 (0.1223)  loss_box_reg: 0.0980 (0.0937)  loss_objectness: 0.0065 (0.0072)  loss_rpn_box_reg: 0.0123 (0.0110)  time: 2.5205  data: 0.0274  max mem: 11382
# Epoch: [0]  [140/751]  eta: 0:24:48  lr: 0.000378  loss: 0.2274 (0.2338)  loss_classifier: 0.1174 (0.1222)  loss_box_reg: 0.0896 (0.0934)  loss_objectness: 0.0062 (0.0073)  loss_rpn_box_reg: 0.0090 (0.0109)  time: 2.5248  data: 0.0267  max mem: 11382
# Epoch: [0]  [150/751]  eta: 0:24:28  lr: 0.000404  loss: 0.2040 (0.2349)  loss_classifier: 0.1166 (0.1229)  loss_box_reg: 0.0798 (0.0937)  loss_objectness: 0.0073 (0.0075)  loss_rpn_box_reg: 0.0096 (0.0109)  time: 2.5345  data: 0.0266  max mem: 11382
# Epoch: [0]  [160/751]  eta: 0:24:08  lr: 0.000431  loss: 0.2140 (0.2333)  loss_classifier: 0.1160 (0.1221)  loss_box_reg: 0.0819 (0.0929)  loss_objectness: 0.0073 (0.0075)  loss_rpn_box_reg: 0.0090 (0.0107)  time: 2.5467  data: 0.0273  max mem: 11382
# Epoch: [0]  [170/751]  eta: 0:23:46  lr: 0.000458  loss: 0.2157 (0.2337)  loss_classifier: 0.1182 (0.1225)  loss_box_reg: 0.0880 (0.0933)  loss_objectness: 0.0057 (0.0074)  loss_rpn_box_reg: 0.0080 (0.0106)  time: 2.5465  data: 0.0274  max mem: 11382
# Epoch: [0]  [180/751]  eta: 0:23:23  lr: 0.000484  loss: 0.2306 (0.2340)  loss_classifier: 0.1187 (0.1226)  loss_box_reg: 0.0952 (0.0933)  loss_objectness: 0.0064 (0.0075)  loss_rpn_box_reg: 0.0079 (0.0105)  time: 2.5180  data: 0.0273  max mem: 11382
# Epoch: [0]  [190/751]  eta: 0:23:01  lr: 0.000511  loss: 0.2093 (0.2332)  loss_classifier: 0.1126 (0.1225)  loss_box_reg: 0.0857 (0.0928)  loss_objectness: 0.0065 (0.0075)  loss_rpn_box_reg: 0.0063 (0.0103)  time: 2.5156  data: 0.0270  max mem: 11382
# Epoch: [0]  [200/751]  eta: 0:22:38  lr: 0.000537  loss: 0.2243 (0.2344)  loss_classifier: 0.1184 (0.1232)  loss_box_reg: 0.0889 (0.0930)  loss_objectness: 0.0065 (0.0076)  loss_rpn_box_reg: 0.0074 (0.0106)  time: 2.5364  data: 0.0268  max mem: 11382
# Epoch: [0]  [210/751]  eta: 0:22:15  lr: 0.000564  loss: 0.2748 (0.2368)  loss_classifier: 0.1451 (0.1243)  loss_box_reg: 0.1033 (0.0939)  loss_objectness: 0.0065 (0.0077)  loss_rpn_box_reg: 0.0116 (0.0109)  time: 2.5400  data: 0.0267  max mem: 11382
# Epoch: [0]  [220/751]  eta: 0:21:52  lr: 0.000591  loss: 0.2244 (0.2366)  loss_classifier: 0.1284 (0.1244)  loss_box_reg: 0.0867 (0.0936)  loss_objectness: 0.0062 (0.0077)  loss_rpn_box_reg: 0.0092 (0.0109)  time: 2.5375  data: 0.0265  max mem: 11382
# Epoch: [0]  [230/751]  eta: 0:21:29  lr: 0.000617  loss: 0.2338 (0.2390)  loss_classifier: 0.1349 (0.1261)  loss_box_reg: 0.0933 (0.0946)  loss_objectness: 0.0067 (0.0076)  loss_rpn_box_reg: 0.0070 (0.0107)  time: 2.5376  data: 0.0267  max mem: 11382
# Epoch: [0]  [240/751]  eta: 0:21:06  lr: 0.000644  loss: 0.2519 (0.2392)  loss_classifier: 0.1434 (0.1262)  loss_box_reg: 0.1001 (0.0948)  loss_objectness: 0.0062 (0.0075)  loss_rpn_box_reg: 0.0078 (0.0107)  time: 2.5434  data: 0.0273  max mem: 11382
# Epoch: [0]  [250/751]  eta: 0:20:42  lr: 0.000671  loss: 0.2179 (0.2392)  loss_classifier: 0.1143 (0.1262)  loss_box_reg: 0.0886 (0.0946)  loss_objectness: 0.0060 (0.0076)  loss_rpn_box_reg: 0.0083 (0.0107)  time: 2.5477  data: 0.0273  max mem: 11382
# Epoch: [0]  [260/751]  eta: 0:20:19  lr: 0.000697  loss: 0.2070 (0.2386)  loss_classifier: 0.1140 (0.1258)  loss_box_reg: 0.0863 (0.0946)  loss_objectness: 0.0043 (0.0075)  loss_rpn_box_reg: 0.0087 (0.0107)  time: 2.5481  data: 0.0265  max mem: 11382
# Epoch: [0]  [270/751]  eta: 0:19:55  lr: 0.000724  loss: 0.2290 (0.2408)  loss_classifier: 0.1251 (0.1272)  loss_box_reg: 0.0905 (0.0954)  loss_objectness: 0.0054 (0.0075)  loss_rpn_box_reg: 0.0092 (0.0106)  time: 2.5471  data: 0.0266  max mem: 11382
# Epoch: [0]  [280/751]  eta: 0:19:31  lr: 0.000751  loss: 0.2843 (0.2428)  loss_classifier: 0.1585 (0.1283)  loss_box_reg: 0.1092 (0.0963)  loss_objectness: 0.0078 (0.0077)  loss_rpn_box_reg: 0.0079 (0.0105)  time: 2.5428  data: 0.0268  max mem: 11382
# Epoch: [0]  [290/751]  eta: 0:19:07  lr: 0.000777  loss: 0.2268 (0.2424)  loss_classifier: 0.1250 (0.1280)  loss_box_reg: 0.0932 (0.0962)  loss_objectness: 0.0080 (0.0077)  loss_rpn_box_reg: 0.0072 (0.0105)  time: 2.5403  data: 0.0270  max mem: 11382
# Epoch: [0]  [300/751]  eta: 0:18:43  lr: 0.000804  loss: 0.2213 (0.2413)  loss_classifier: 0.1216 (0.1275)  loss_box_reg: 0.0864 (0.0958)  loss_objectness: 0.0069 (0.0077)  loss_rpn_box_reg: 0.0072 (0.0104)  time: 2.5475  data: 0.0270  max mem: 11382
# Epoch: [0]  [310/751]  eta: 0:18:19  lr: 0.000831  loss: 0.2058 (0.2407)  loss_classifier: 0.1079 (0.1271)  loss_box_reg: 0.0852 (0.0956)  loss_objectness: 0.0053 (0.0076)  loss_rpn_box_reg: 0.0084 (0.0103)  time: 2.5521  data: 0.0277  max mem: 11382
# Epoch: [0]  [320/751]  eta: 0:17:55  lr: 0.000857  loss: 0.2032 (0.2395)  loss_classifier: 0.1059 (0.1266)  loss_box_reg: 0.0841 (0.0952)  loss_objectness: 0.0046 (0.0075)  loss_rpn_box_reg: 0.0067 (0.0103)  time: 2.5541  data: 0.0285  max mem: 11382
# Epoch: [0]  [330/751]  eta: 0:17:31  lr: 0.000884  loss: 0.2076 (0.2408)  loss_classifier: 0.1029 (0.1273)  loss_box_reg: 0.0834 (0.0957)  loss_objectness: 0.0046 (0.0075)  loss_rpn_box_reg: 0.0087 (0.0104)  time: 2.5566  data: 0.0278  max mem: 11382
# Epoch: [0]  [340/751]  eta: 0:17:07  lr: 0.000910  loss: 0.2076 (0.2397)  loss_classifier: 0.1084 (0.1267)  loss_box_reg: 0.0784 (0.0952)  loss_objectness: 0.0045 (0.0074)  loss_rpn_box_reg: 0.0088 (0.0103)  time: 2.5540  data: 0.0270  max mem: 11382
# Epoch: [0]  [350/751]  eta: 0:16:42  lr: 0.000937  loss: 0.1923 (0.2398)  loss_classifier: 0.1084 (0.1269)  loss_box_reg: 0.0779 (0.0951)  loss_objectness: 0.0069 (0.0075)  loss_rpn_box_reg: 0.0075 (0.0104)  time: 2.5536  data: 0.0272  max mem: 11382
# Epoch: [0]  [360/751]  eta: 0:16:17  lr: 0.000964  loss: 0.2136 (0.2389)  loss_classifier: 0.1089 (0.1263)  loss_box_reg: 0.0806 (0.0947)  loss_objectness: 0.0069 (0.0075)  loss_rpn_box_reg: 0.0072 (0.0104)  time: 2.5290  data: 0.0280  max mem: 11382
# Epoch: [0]  [370/751]  eta: 0:15:53  lr: 0.000990  loss: 0.2080 (0.2381)  loss_classifier: 0.1014 (0.1258)  loss_box_reg: 0.0854 (0.0945)  loss_objectness: 0.0046 (0.0074)  loss_rpn_box_reg: 0.0071 (0.0103)  time: 2.5230  data: 0.0280  max mem: 11382
# Epoch: [0]  [380/751]  eta: 0:15:28  lr: 0.001017  loss: 0.2080 (0.2374)  loss_classifier: 0.1014 (0.1255)  loss_box_reg: 0.0854 (0.0942)  loss_objectness: 0.0040 (0.0074)  loss_rpn_box_reg: 0.0069 (0.0103)  time: 2.5439  data: 0.0273  max mem: 11382
# Epoch: [0]  [390/751]  eta: 0:15:03  lr: 0.001044  loss: 0.1676 (0.2361)  loss_classifier: 0.0907 (0.1248)  loss_box_reg: 0.0676 (0.0937)  loss_objectness: 0.0039 (0.0074)  loss_rpn_box_reg: 0.0069 (0.0102)  time: 2.5467  data: 0.0276  max mem: 11382
# Epoch: [0]  [400/751]  eta: 0:14:39  lr: 0.001070  loss: 0.1889 (0.2355)  loss_classifier: 0.0907 (0.1244)  loss_box_reg: 0.0701 (0.0934)  loss_objectness: 0.0045 (0.0074)  loss_rpn_box_reg: 0.0078 (0.0103)  time: 2.5557  data: 0.0279  max mem: 11382
# Epoch: [0]  [410/751]  eta: 0:14:14  lr: 0.001097  loss: 0.1983 (0.2357)  loss_classifier: 0.1108 (0.1245)  loss_box_reg: 0.0833 (0.0936)  loss_objectness: 0.0066 (0.0074)  loss_rpn_box_reg: 0.0089 (0.0103)  time: 2.5526  data: 0.0275  max mem: 11382
# Epoch: [0]  [420/751]  eta: 0:13:49  lr: 0.001124  loss: 0.2288 (0.2364)  loss_classifier: 0.1129 (0.1248)  loss_box_reg: 0.0965 (0.0938)  loss_objectness: 0.0076 (0.0075)  loss_rpn_box_reg: 0.0087 (0.0103)  time: 2.5432  data: 0.0265  max mem: 11382
# Epoch: [0]  [430/751]  eta: 0:13:25  lr: 0.001150  loss: 0.2200 (0.2366)  loss_classifier: 0.1179 (0.1249)  loss_box_reg: 0.0885 (0.0939)  loss_objectness: 0.0060 (0.0075)  loss_rpn_box_reg: 0.0083 (0.0103)  time: 2.5453  data: 0.0263  max mem: 11382
# Epoch: [0]  [440/751]  eta: 0:13:00  lr: 0.001177  loss: 0.2036 (0.2360)  loss_classifier: 0.1093 (0.1246)  loss_box_reg: 0.0861 (0.0937)  loss_objectness: 0.0040 (0.0075)  loss_rpn_box_reg: 0.0063 (0.0102)  time: 2.5430  data: 0.0265  max mem: 11382
# Epoch: [0]  [450/751]  eta: 0:12:35  lr: 0.001203  loss: 0.1878 (0.2353)  loss_classifier: 0.1026 (0.1243)  loss_box_reg: 0.0784 (0.0934)  loss_objectness: 0.0035 (0.0074)  loss_rpn_box_reg: 0.0069 (0.0102)  time: 2.5392  data: 0.0265  max mem: 11382
# Epoch: [0]  [460/751]  eta: 0:12:10  lr: 0.001230  loss: 0.2145 (0.2354)  loss_classifier: 0.1118 (0.1242)  loss_box_reg: 0.0784 (0.0935)  loss_objectness: 0.0046 (0.0074)  loss_rpn_box_reg: 0.0080 (0.0103)  time: 2.5403  data: 0.0270  max mem: 11382
# Epoch: [0]  [470/751]  eta: 0:11:45  lr: 0.001257  loss: 0.2268 (0.2354)  loss_classifier: 0.1260 (0.1243)  loss_box_reg: 0.0818 (0.0934)  loss_objectness: 0.0046 (0.0074)  loss_rpn_box_reg: 0.0085 (0.0103)  time: 2.5439  data: 0.0266  max mem: 11382
# Epoch: [0]  [480/751]  eta: 0:11:20  lr: 0.001283  loss: 0.2191 (0.2347)  loss_classifier: 0.1208 (0.1239)  loss_box_reg: 0.0797 (0.0931)  loss_objectness: 0.0046 (0.0074)  loss_rpn_box_reg: 0.0085 (0.0103)  time: 2.5513  data: 0.0269  max mem: 11382
# Epoch: [0]  [490/751]  eta: 0:10:55  lr: 0.001310  loss: 0.2060 (0.2348)  loss_classifier: 0.1034 (0.1240)  loss_box_reg: 0.0826 (0.0931)  loss_objectness: 0.0049 (0.0074)  loss_rpn_box_reg: 0.0071 (0.0103)  time: 2.5527  data: 0.0271  max mem: 11382
# Epoch: [0]  [500/751]  eta: 0:10:30  lr: 0.001337  loss: 0.2236 (0.2347)  loss_classifier: 0.1163 (0.1240)  loss_box_reg: 0.0889 (0.0931)  loss_objectness: 0.0049 (0.0074)  loss_rpn_box_reg: 0.0077 (0.0102)  time: 2.5478  data: 0.0273  max mem: 11382
# Epoch: [0]  [510/751]  eta: 0:10:05  lr: 0.001363  loss: 0.1966 (0.2349)  loss_classifier: 0.1101 (0.1241)  loss_box_reg: 0.0884 (0.0932)  loss_objectness: 0.0053 (0.0074)  loss_rpn_box_reg: 0.0081 (0.0103)  time: 2.5448  data: 0.0271  max mem: 11382
# Epoch: [0]  [520/751]  eta: 0:09:40  lr: 0.001390  loss: 0.2061 (0.2345)  loss_classifier: 0.0976 (0.1239)  loss_box_reg: 0.0705 (0.0929)  loss_objectness: 0.0055 (0.0074)  loss_rpn_box_reg: 0.0092 (0.0103)  time: 2.5401  data: 0.0267  max mem: 11382
# Epoch: [0]  [530/751]  eta: 0:09:15  lr: 0.001417  loss: 0.1967 (0.2337)  loss_classifier: 0.0990 (0.1234)  loss_box_reg: 0.0723 (0.0926)  loss_objectness: 0.0051 (0.0074)  loss_rpn_box_reg: 0.0072 (0.0102)  time: 2.5389  data: 0.0266  max mem: 11382
# Epoch: [0]  [540/751]  eta: 0:08:50  lr: 0.001443  loss: 0.1958 (0.2333)  loss_classifier: 0.1091 (0.1233)  loss_box_reg: 0.0725 (0.0924)  loss_objectness: 0.0051 (0.0074)  loss_rpn_box_reg: 0.0062 (0.0102)  time: 2.5436  data: 0.0265  max mem: 11382
# Epoch: [0]  [550/751]  eta: 0:08:25  lr: 0.001470  loss: 0.2074 (0.2334)  loss_classifier: 0.1181 (0.1234)  loss_box_reg: 0.0815 (0.0924)  loss_objectness: 0.0057 (0.0074)  loss_rpn_box_reg: 0.0070 (0.0102)  time: 2.5428  data: 0.0269  max mem: 11382
# Epoch: [0]  [560/751]  eta: 0:08:00  lr: 0.001497  loss: 0.1951 (0.2326)  loss_classifier: 0.1050 (0.1230)  loss_box_reg: 0.0756 (0.0921)  loss_objectness: 0.0055 (0.0074)  loss_rpn_box_reg: 0.0074 (0.0101)  time: 2.5472  data: 0.0270  max mem: 11382
# Epoch: [0]  [570/751]  eta: 0:07:35  lr: 0.001523  loss: 0.1951 (0.2323)  loss_classifier: 0.0984 (0.1229)  loss_box_reg: 0.0755 (0.0919)  loss_objectness: 0.0045 (0.0074)  loss_rpn_box_reg: 0.0085 (0.0101)  time: 2.5447  data: 0.0272  max mem: 11382
# Epoch: [0]  [580/751]  eta: 0:07:10  lr: 0.001550  loss: 0.2220 (0.2329)  loss_classifier: 0.1167 (0.1232)  loss_box_reg: 0.0934 (0.0922)  loss_objectness: 0.0051 (0.0075)  loss_rpn_box_reg: 0.0072 (0.0101)  time: 2.5404  data: 0.0278  max mem: 11382
# Epoch: [0]  [590/751]  eta: 0:06:45  lr: 0.001576  loss: 0.2220 (0.2325)  loss_classifier: 0.1113 (0.1230)  loss_box_reg: 0.0888 (0.0919)  loss_objectness: 0.0063 (0.0074)  loss_rpn_box_reg: 0.0088 (0.0101)  time: 2.5487  data: 0.0284  max mem: 11382
# Epoch: [0]  [600/751]  eta: 0:06:20  lr: 0.001603  loss: 0.1952 (0.2323)  loss_classifier: 0.1088 (0.1228)  loss_box_reg: 0.0762 (0.0918)  loss_objectness: 0.0063 (0.0075)  loss_rpn_box_reg: 0.0083 (0.0101)  time: 2.5408  data: 0.0276  max mem: 11382
# Epoch: [0]  [610/751]  eta: 0:05:55  lr: 0.001630  loss: 0.2215 (0.2322)  loss_classifier: 0.1104 (0.1227)  loss_box_reg: 0.0976 (0.0919)  loss_objectness: 0.0063 (0.0075)  loss_rpn_box_reg: 0.0083 (0.0101)  time: 2.5338  data: 0.0263  max mem: 11382
# Epoch: [0]  [620/751]  eta: 0:05:30  lr: 0.001656  loss: 0.1986 (0.2316)  loss_classifier: 0.1022 (0.1224)  loss_box_reg: 0.0850 (0.0917)  loss_objectness: 0.0053 (0.0075)  loss_rpn_box_reg: 0.0083 (0.0101)  time: 2.5442  data: 0.0265  max mem: 11382
# Epoch: [0]  [630/751]  eta: 0:05:04  lr: 0.001683  loss: 0.2013 (0.2320)  loss_classifier: 0.1078 (0.1226)  loss_box_reg: 0.0880 (0.0918)  loss_objectness: 0.0057 (0.0075)  loss_rpn_box_reg: 0.0082 (0.0101)  time: 2.5549  data: 0.0269  max mem: 11382
# Epoch: [0]  [640/751]  eta: 0:04:39  lr: 0.001710  loss: 0.2323 (0.2322)  loss_classifier: 0.1168 (0.1226)  loss_box_reg: 0.0891 (0.0919)  loss_objectness: 0.0069 (0.0075)  loss_rpn_box_reg: 0.0080 (0.0102)  time: 2.5384  data: 0.0272  max mem: 11382
# Epoch: [0]  [650/751]  eta: 0:04:14  lr: 0.001736  loss: 0.2383 (0.2324)  loss_classifier: 0.1184 (0.1227)  loss_box_reg: 0.0891 (0.0920)  loss_objectness: 0.0074 (0.0075)  loss_rpn_box_reg: 0.0101 (0.0102)  time: 2.5270  data: 0.0271  max mem: 11382
# Epoch: [0]  [660/751]  eta: 0:03:49  lr: 0.001763  loss: 0.2208 (0.2325)  loss_classifier: 0.1101 (0.1227)  loss_box_reg: 0.0859 (0.0922)  loss_objectness: 0.0047 (0.0074)  loss_rpn_box_reg: 0.0083 (0.0101)  time: 2.5385  data: 0.0266  max mem: 11382
# Epoch: [0]  [670/751]  eta: 0:03:24  lr: 0.001790  loss: 0.1971 (0.2320)  loss_classifier: 0.1101 (0.1225)  loss_box_reg: 0.0782 (0.0919)  loss_objectness: 0.0034 (0.0074)  loss_rpn_box_reg: 0.0069 (0.0101)  time: 2.5398  data: 0.0263  max mem: 11382
# Epoch: [0]  [680/751]  eta: 0:02:58  lr: 0.001816  loss: 0.1977 (0.2320)  loss_classifier: 0.0940 (0.1223)  loss_box_reg: 0.0684 (0.0919)  loss_objectness: 0.0047 (0.0077)  loss_rpn_box_reg: 0.0062 (0.0101)  time: 2.5437  data: 0.0269  max mem: 11382
# Epoch: [0]  [690/751]  eta: 0:02:33  lr: 0.001843  loss: 0.1934 (0.2315)  loss_classifier: 0.0953 (0.1221)  loss_box_reg: 0.0720 (0.0916)  loss_objectness: 0.0057 (0.0077)  loss_rpn_box_reg: 0.0056 (0.0101)  time: 2.5436  data: 0.0268  max mem: 11382
# Epoch: [0]  [700/751]  eta: 0:02:08  lr: 0.001869  loss: 0.2111 (0.2320)  loss_classifier: 0.1197 (0.1223)  loss_box_reg: 0.0812 (0.0918)  loss_objectness: 0.0062 (0.0078)  loss_rpn_box_reg: 0.0066 (0.0101)  time: 2.5440  data: 0.0265  max mem: 11382
# Epoch: [0]  [710/751]  eta: 0:01:43  lr: 0.001896  loss: 0.2022 (0.2314)  loss_classifier: 0.1064 (0.1219)  loss_box_reg: 0.0812 (0.0916)  loss_objectness: 0.0049 (0.0077)  loss_rpn_box_reg: 0.0078 (0.0101)  time: 2.5483  data: 0.0279  max mem: 11382
# Epoch: [0]  [720/751]  eta: 0:01:18  lr: 0.001923  loss: 0.1892 (0.2311)  loss_classifier: 0.1044 (0.1217)  loss_box_reg: 0.0748 (0.0915)  loss_objectness: 0.0049 (0.0078)  loss_rpn_box_reg: 0.0074 (0.0101)  time: 2.5431  data: 0.0278  max mem: 11382
# Epoch: [0]  [730/751]  eta: 0:00:52  lr: 0.001949  loss: 0.1892 (0.2304)  loss_classifier: 0.1044 (0.1214)  loss_box_reg: 0.0748 (0.0913)  loss_objectness: 0.0046 (0.0077)  loss_rpn_box_reg: 0.0070 (0.0100)  time: 2.5256  data: 0.0271  max mem: 11382
# Epoch: [0]  [740/751]  eta: 0:00:27  lr: 0.001976  loss: 0.1928 (0.2302)  loss_classifier: 0.0946 (0.1212)  loss_box_reg: 0.0779 (0.0912)  loss_objectness: 0.0046 (0.0077)  loss_rpn_box_reg: 0.0077 (0.0100)  time: 2.5333  data: 0.0280  max mem: 11382
# Epoch: [0]  [750/751]  eta: 0:00:02  lr: 0.002000  loss: 0.1979 (0.2298)  loss_classifier: 0.0944 (0.1209)  loss_box_reg: 0.0820 (0.0912)  loss_objectness: 0.0050 (0.0077)  loss_rpn_box_reg: 0.0083 (0.0100)  time: 2.5463  data: 0.0278  max mem: 11382
# Epoch: [0] Total time: 0:31:35 (2.5233 s / it)
# creating index...
# index created!
# Test:  [  0/108]  eta: 0:02:24  model_time: 1.0432 (1.0432)  evaluator_time: 0.0092 (0.0092)  time: 1.3411  data: 0.2823  max mem: 11382
# Test:  [100/108]  eta: 0:00:08  model_time: 1.0895 (1.0486)  evaluator_time: 0.0095 (0.0107)  time: 1.1043  data: 0.0250  max mem: 11382
# Test:  [107/108]  eta: 0:00:01  model_time: 0.9633 (1.0408)  evaluator_time: 0.0081 (0.0105)  time: 1.0450  data: 0.0254  max mem: 11382
# Test: Total time: 0:01:57 (1.0862 s / it)
# Averaged stats: model_time: 0.9633 (1.0408)  evaluator_time: 0.0081 (0.0105)
# Accumulating evaluation results...
# DONE (t=0.42s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.106
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.210
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.090
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.066
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.112
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.126
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.202
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.258
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.258
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.183
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.281
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.217
# Epoch: [1]  [  0/751]  eta: 0:34:11  lr: 0.002000  loss: 0.1507 (0.1507)  loss_classifier: 0.0691 (0.0691)  loss_box_reg: 0.0736 (0.0736)  loss_objectness: 0.0031 (0.0031)  loss_rpn_box_reg: 0.0049 (0.0049)  time: 2.7317  data: 0.2548  max mem: 11382
# Epoch: [1]  [ 20/751]  eta: 0:30:57  lr: 0.002000  loss: 0.1690 (0.1852)  loss_classifier: 0.0929 (0.0944)  loss_box_reg: 0.0722 (0.0750)  loss_objectness: 0.0042 (0.0063)  loss_rpn_box_reg: 0.0070 (0.0095)  time: 2.5321  data: 0.0260  max mem: 11382
# Epoch: [1]  [ 30/751]  eta: 0:30:31  lr: 0.002000  loss: 0.1788 (0.1902)  loss_classifier: 0.0978 (0.0945)  loss_box_reg: 0.0784 (0.0801)  loss_objectness: 0.0034 (0.0056)  loss_rpn_box_reg: 0.0070 (0.0100)  time: 2.5436  data: 0.0260  max mem: 11382
# Epoch: [1]  [ 40/751]  eta: 0:30:04  lr: 0.002000  loss: 0.2038 (0.1933)  loss_classifier: 0.0978 (0.0968)  loss_box_reg: 0.0844 (0.0803)  loss_objectness: 0.0034 (0.0056)  loss_rpn_box_reg: 0.0072 (0.0106)  time: 2.5345  data: 0.0265  max mem: 11382
# Epoch: [1]  [ 50/751]  eta: 0:29:41  lr: 0.002000  loss: 0.1589 (0.1894)  loss_classifier: 0.0862 (0.0948)  loss_box_reg: 0.0687 (0.0793)  loss_objectness: 0.0043 (0.0052)  loss_rpn_box_reg: 0.0071 (0.0101)  time: 2.5455  data: 0.0272  max mem: 11382
# Epoch: [1]  [ 60/751]  eta: 0:29:17  lr: 0.002000  loss: 0.1681 (0.1933)  loss_classifier: 0.0814 (0.0970)  loss_box_reg: 0.0722 (0.0801)  loss_objectness: 0.0050 (0.0058)  loss_rpn_box_reg: 0.0082 (0.0104)  time: 2.5544  data: 0.0267  max mem: 11382
# Epoch: [1]  [ 70/751]  eta: 0:28:51  lr: 0.002000  loss: 0.1974 (0.1957)  loss_classifier: 0.1010 (0.0981)  loss_box_reg: 0.0751 (0.0806)  loss_objectness: 0.0071 (0.0062)  loss_rpn_box_reg: 0.0115 (0.0108)  time: 2.5435  data: 0.0263  max mem: 11382
# Epoch: [1]  [ 80/751]  eta: 0:28:24  lr: 0.002000  loss: 0.1807 (0.1940)  loss_classifier: 0.0853 (0.0966)  loss_box_reg: 0.0715 (0.0797)  loss_objectness: 0.0064 (0.0064)  loss_rpn_box_reg: 0.0115 (0.0112)  time: 2.5332  data: 0.0266  max mem: 11382
# Epoch: [1]  [ 90/751]  eta: 0:28:00  lr: 0.002000  loss: 0.1807 (0.1932)  loss_classifier: 0.0837 (0.0966)  loss_box_reg: 0.0724 (0.0791)  loss_objectness: 0.0053 (0.0064)  loss_rpn_box_reg: 0.0095 (0.0112)  time: 2.5399  data: 0.0269  max mem: 11382
# Epoch: [1]  [100/751]  eta: 0:27:36  lr: 0.002000  loss: 0.1857 (0.1946)  loss_classifier: 0.0870 (0.0974)  loss_box_reg: 0.0817 (0.0795)  loss_objectness: 0.0057 (0.0063)  loss_rpn_box_reg: 0.0083 (0.0113)  time: 2.5565  data: 0.0265  max mem: 11382
# Epoch: [1]  [110/751]  eta: 0:27:11  lr: 0.002000  loss: 0.1801 (0.1926)  loss_classifier: 0.0870 (0.0965)  loss_box_reg: 0.0771 (0.0787)  loss_objectness: 0.0045 (0.0063)  loss_rpn_box_reg: 0.0090 (0.0111)  time: 2.5577  data: 0.0263  max mem: 11382
# Epoch: [1]  [120/751]  eta: 0:26:45  lr: 0.002000  loss: 0.1905 (0.1963)  loss_classifier: 0.0943 (0.0982)  loss_box_reg: 0.0811 (0.0802)  loss_objectness: 0.0064 (0.0067)  loss_rpn_box_reg: 0.0100 (0.0112)  time: 2.5480  data: 0.0271  max mem: 11382
# Epoch: [1]  [130/751]  eta: 0:26:19  lr: 0.002000  loss: 0.1992 (0.1961)  loss_classifier: 0.1072 (0.0985)  loss_box_reg: 0.0843 (0.0801)  loss_objectness: 0.0049 (0.0065)  loss_rpn_box_reg: 0.0089 (0.0110)  time: 2.5412  data: 0.0272  max mem: 11382
# Epoch: [1]  [140/751]  eta: 0:25:54  lr: 0.002000  loss: 0.1743 (0.1937)  loss_classifier: 0.0883 (0.0972)  loss_box_reg: 0.0750 (0.0793)  loss_objectness: 0.0034 (0.0064)  loss_rpn_box_reg: 0.0077 (0.0108)  time: 2.5418  data: 0.0268  max mem: 11382
# Epoch: [1]  [150/751]  eta: 0:25:29  lr: 0.002000  loss: 0.1769 (0.1961)  loss_classifier: 0.0922 (0.0987)  loss_box_reg: 0.0754 (0.0804)  loss_objectness: 0.0046 (0.0063)  loss_rpn_box_reg: 0.0077 (0.0107)  time: 2.5440  data: 0.0265  max mem: 11382
# Epoch: [1]  [160/751]  eta: 0:25:03  lr: 0.002000  loss: 0.1880 (0.1935)  loss_classifier: 0.0942 (0.0975)  loss_box_reg: 0.0741 (0.0793)  loss_objectness: 0.0044 (0.0062)  loss_rpn_box_reg: 0.0061 (0.0106)  time: 2.5454  data: 0.0263  max mem: 11382
# Epoch: [1]  [170/751]  eta: 0:24:38  lr: 0.002000  loss: 0.1450 (0.1913)  loss_classifier: 0.0766 (0.0963)  loss_box_reg: 0.0551 (0.0782)  loss_objectness: 0.0049 (0.0064)  loss_rpn_box_reg: 0.0061 (0.0104)  time: 2.5508  data: 0.0264  max mem: 11382
# Epoch: [1]  [180/751]  eta: 0:24:12  lr: 0.002000  loss: 0.1512 (0.1898)  loss_classifier: 0.0766 (0.0955)  loss_box_reg: 0.0631 (0.0777)  loss_objectness: 0.0060 (0.0064)  loss_rpn_box_reg: 0.0060 (0.0103)  time: 2.5335  data: 0.0268  max mem: 11382
# Epoch: [1]  [190/751]  eta: 0:23:46  lr: 0.002000  loss: 0.1766 (0.1912)  loss_classifier: 0.0911 (0.0961)  loss_box_reg: 0.0774 (0.0782)  loss_objectness: 0.0060 (0.0067)  loss_rpn_box_reg: 0.0061 (0.0102)  time: 2.5325  data: 0.0272  max mem: 11382
# Epoch: [1]  [200/751]  eta: 0:23:21  lr: 0.002000  loss: 0.2293 (0.1944)  loss_classifier: 0.1136 (0.0977)  loss_box_reg: 0.0871 (0.0795)  loss_objectness: 0.0061 (0.0068)  loss_rpn_box_reg: 0.0080 (0.0103)  time: 2.5493  data: 0.0271  max mem: 11382
# Epoch: [1]  [210/751]  eta: 0:22:56  lr: 0.002000  loss: 0.2182 (0.1962)  loss_classifier: 0.1212 (0.0988)  loss_box_reg: 0.0875 (0.0803)  loss_objectness: 0.0064 (0.0069)  loss_rpn_box_reg: 0.0069 (0.0102)  time: 2.5422  data: 0.0269  max mem: 11382
# Epoch: [1]  [220/751]  eta: 0:22:30  lr: 0.002000  loss: 0.2119 (0.1964)  loss_classifier: 0.1076 (0.0991)  loss_box_reg: 0.0828 (0.0803)  loss_objectness: 0.0052 (0.0069)  loss_rpn_box_reg: 0.0071 (0.0101)  time: 2.5380  data: 0.0265  max mem: 11382
# Epoch: [1]  [230/751]  eta: 0:22:05  lr: 0.002000  loss: 0.1790 (0.1951)  loss_classifier: 0.0841 (0.0984)  loss_box_reg: 0.0748 (0.0800)  loss_objectness: 0.0037 (0.0068)  loss_rpn_box_reg: 0.0073 (0.0100)  time: 2.5408  data: 0.0269  max mem: 11382
# Epoch: [1]  [240/751]  eta: 0:21:39  lr: 0.002000  loss: 0.1585 (0.1942)  loss_classifier: 0.0780 (0.0977)  loss_box_reg: 0.0650 (0.0797)  loss_objectness: 0.0066 (0.0068)  loss_rpn_box_reg: 0.0075 (0.0100)  time: 2.5443  data: 0.0275  max mem: 11382
# Epoch: [1]  [250/751]  eta: 0:21:14  lr: 0.002000  loss: 0.1659 (0.1939)  loss_classifier: 0.0801 (0.0975)  loss_box_reg: 0.0765 (0.0798)  loss_objectness: 0.0034 (0.0067)  loss_rpn_box_reg: 0.0075 (0.0099)  time: 2.5405  data: 0.0273  max mem: 11382
# Epoch: [1]  [260/751]  eta: 0:20:48  lr: 0.002000  loss: 0.1752 (0.1938)  loss_classifier: 0.0931 (0.0973)  loss_box_reg: 0.0855 (0.0800)  loss_objectness: 0.0030 (0.0066)  loss_rpn_box_reg: 0.0069 (0.0098)  time: 2.5352  data: 0.0272  max mem: 11382
# Epoch: [1]  [270/751]  eta: 0:20:23  lr: 0.002000  loss: 0.1752 (0.1938)  loss_classifier: 0.0942 (0.0973)  loss_box_reg: 0.0808 (0.0802)  loss_objectness: 0.0033 (0.0066)  loss_rpn_box_reg: 0.0061 (0.0098)  time: 2.5418  data: 0.0284  max mem: 11382
# Epoch: [1]  [280/751]  eta: 0:19:58  lr: 0.002000  loss: 0.1808 (0.1942)  loss_classifier: 0.0942 (0.0973)  loss_box_reg: 0.0801 (0.0806)  loss_objectness: 0.0045 (0.0065)  loss_rpn_box_reg: 0.0069 (0.0098)  time: 2.5554  data: 0.0285  max mem: 11382
# Epoch: [1]  [290/751]  eta: 0:19:32  lr: 0.002000  loss: 0.1831 (0.1941)  loss_classifier: 0.0911 (0.0971)  loss_box_reg: 0.0794 (0.0806)  loss_objectness: 0.0045 (0.0065)  loss_rpn_box_reg: 0.0086 (0.0098)  time: 2.5608  data: 0.0269  max mem: 11382
# Epoch: [1]  [300/751]  eta: 0:19:07  lr: 0.002000  loss: 0.1556 (0.1930)  loss_classifier: 0.0700 (0.0964)  loss_box_reg: 0.0724 (0.0804)  loss_objectness: 0.0040 (0.0065)  loss_rpn_box_reg: 0.0069 (0.0098)  time: 2.5492  data: 0.0265  max mem: 11382
# Epoch: [1]  [310/751]  eta: 0:18:41  lr: 0.002000  loss: 0.1379 (0.1916)  loss_classifier: 0.0631 (0.0957)  loss_box_reg: 0.0632 (0.0799)  loss_objectness: 0.0027 (0.0064)  loss_rpn_box_reg: 0.0053 (0.0096)  time: 2.5357  data: 0.0273  max mem: 11382
# Epoch: [1]  [320/751]  eta: 0:18:16  lr: 0.002000  loss: 0.1526 (0.1935)  loss_classifier: 0.0827 (0.0967)  loss_box_reg: 0.0730 (0.0807)  loss_objectness: 0.0036 (0.0065)  loss_rpn_box_reg: 0.0068 (0.0096)  time: 2.5270  data: 0.0278  max mem: 11382
# Epoch: [1]  [330/751]  eta: 0:17:50  lr: 0.002000  loss: 0.1747 (0.1924)  loss_classifier: 0.0866 (0.0963)  loss_box_reg: 0.0690 (0.0802)  loss_objectness: 0.0036 (0.0064)  loss_rpn_box_reg: 0.0072 (0.0095)  time: 2.5314  data: 0.0277  max mem: 11382
# Epoch: [1]  [340/751]  eta: 0:17:25  lr: 0.002000  loss: 0.1471 (0.1915)  loss_classifier: 0.0789 (0.0958)  loss_box_reg: 0.0606 (0.0798)  loss_objectness: 0.0036 (0.0064)  loss_rpn_box_reg: 0.0058 (0.0095)  time: 2.5465  data: 0.0279  max mem: 11382
# Epoch: [1]  [350/751]  eta: 0:16:59  lr: 0.002000  loss: 0.1447 (0.1915)  loss_classifier: 0.0724 (0.0958)  loss_box_reg: 0.0618 (0.0799)  loss_objectness: 0.0040 (0.0063)  loss_rpn_box_reg: 0.0071 (0.0095)  time: 2.5499  data: 0.0273  max mem: 11382
# Epoch: [1]  [360/751]  eta: 0:16:34  lr: 0.002000  loss: 0.1764 (0.1917)  loss_classifier: 0.0939 (0.0959)  loss_box_reg: 0.0750 (0.0801)  loss_objectness: 0.0042 (0.0063)  loss_rpn_box_reg: 0.0071 (0.0094)  time: 2.5408  data: 0.0270  max mem: 11382
# Epoch: [1]  [370/751]  eta: 0:16:08  lr: 0.002000  loss: 0.1751 (0.1910)  loss_classifier: 0.0839 (0.0956)  loss_box_reg: 0.0841 (0.0799)  loss_objectness: 0.0034 (0.0062)  loss_rpn_box_reg: 0.0066 (0.0094)  time: 2.5403  data: 0.0272  max mem: 11382
# Epoch: [1]  [380/751]  eta: 0:15:43  lr: 0.002000  loss: 0.1929 (0.1917)  loss_classifier: 0.0895 (0.0960)  loss_box_reg: 0.0841 (0.0801)  loss_objectness: 0.0034 (0.0063)  loss_rpn_box_reg: 0.0059 (0.0093)  time: 2.5517  data: 0.0272  max mem: 11382
# Epoch: [1]  [390/751]  eta: 0:15:18  lr: 0.002000  loss: 0.1682 (0.1911)  loss_classifier: 0.0914 (0.0958)  loss_box_reg: 0.0719 (0.0797)  loss_objectness: 0.0047 (0.0063)  loss_rpn_box_reg: 0.0059 (0.0093)  time: 2.5534  data: 0.0275  max mem: 11382
# Epoch: [1]  [400/751]  eta: 0:14:52  lr: 0.002000  loss: 0.1660 (0.1914)  loss_classifier: 0.0833 (0.0959)  loss_box_reg: 0.0695 (0.0798)  loss_objectness: 0.0048 (0.0064)  loss_rpn_box_reg: 0.0056 (0.0094)  time: 2.5445  data: 0.0285  max mem: 11382
# Epoch: [1]  [410/751]  eta: 0:14:27  lr: 0.002000  loss: 0.1835 (0.1924)  loss_classifier: 0.0981 (0.0964)  loss_box_reg: 0.0753 (0.0803)  loss_objectness: 0.0051 (0.0064)  loss_rpn_box_reg: 0.0061 (0.0094)  time: 2.5429  data: 0.0292  max mem: 11382
# Epoch: [1]  [420/751]  eta: 0:14:02  lr: 0.002000  loss: 0.1817 (0.1922)  loss_classifier: 0.0981 (0.0963)  loss_box_reg: 0.0903 (0.0802)  loss_objectness: 0.0041 (0.0063)  loss_rpn_box_reg: 0.0062 (0.0093)  time: 2.5519  data: 0.0280  max mem: 11382
# Epoch: [1]  [430/751]  eta: 0:13:36  lr: 0.002000  loss: 0.1670 (0.1915)  loss_classifier: 0.0775 (0.0959)  loss_box_reg: 0.0750 (0.0800)  loss_objectness: 0.0030 (0.0063)  loss_rpn_box_reg: 0.0062 (0.0093)  time: 2.5520  data: 0.0275  max mem: 11382
# Epoch: [1]  [440/751]  eta: 0:13:11  lr: 0.002000  loss: 0.1534 (0.1912)  loss_classifier: 0.0750 (0.0957)  loss_box_reg: 0.0682 (0.0800)  loss_objectness: 0.0032 (0.0062)  loss_rpn_box_reg: 0.0064 (0.0093)  time: 2.5445  data: 0.0278  max mem: 11382
# Epoch: [1]  [450/751]  eta: 0:12:45  lr: 0.002000  loss: 0.1783 (0.1915)  loss_classifier: 0.0871 (0.0958)  loss_box_reg: 0.0801 (0.0802)  loss_objectness: 0.0036 (0.0062)  loss_rpn_box_reg: 0.0065 (0.0093)  time: 2.5410  data: 0.0269  max mem: 11382
# Epoch: [1]  [460/751]  eta: 0:12:20  lr: 0.002000  loss: 0.1568 (0.1905)  loss_classifier: 0.0772 (0.0953)  loss_box_reg: 0.0581 (0.0797)  loss_objectness: 0.0044 (0.0062)  loss_rpn_box_reg: 0.0082 (0.0093)  time: 2.5379  data: 0.0268  max mem: 11382
# Epoch: [1]  [470/751]  eta: 0:11:54  lr: 0.002000  loss: 0.1526 (0.1899)  loss_classifier: 0.0728 (0.0949)  loss_box_reg: 0.0556 (0.0795)  loss_objectness: 0.0037 (0.0062)  loss_rpn_box_reg: 0.0079 (0.0093)  time: 2.5403  data: 0.0273  max mem: 11382
# Epoch: [1]  [480/751]  eta: 0:11:29  lr: 0.002000  loss: 0.1442 (0.1891)  loss_classifier: 0.0658 (0.0944)  loss_box_reg: 0.0608 (0.0793)  loss_objectness: 0.0038 (0.0062)  loss_rpn_box_reg: 0.0053 (0.0093)  time: 2.5275  data: 0.0273  max mem: 11382
# Epoch: [1]  [490/751]  eta: 0:11:03  lr: 0.002000  loss: 0.1442 (0.1887)  loss_classifier: 0.0743 (0.0943)  loss_box_reg: 0.0642 (0.0790)  loss_objectness: 0.0038 (0.0061)  loss_rpn_box_reg: 0.0051 (0.0092)  time: 2.5234  data: 0.0274  max mem: 11382
# Epoch: [1]  [500/751]  eta: 0:10:38  lr: 0.002000  loss: 0.1490 (0.1882)  loss_classifier: 0.0743 (0.0938)  loss_box_reg: 0.0654 (0.0789)  loss_objectness: 0.0036 (0.0061)  loss_rpn_box_reg: 0.0078 (0.0093)  time: 2.5415  data: 0.0270  max mem: 11382
# Epoch: [1]  [510/751]  eta: 0:10:12  lr: 0.002000  loss: 0.1480 (0.1874)  loss_classifier: 0.0690 (0.0934)  loss_box_reg: 0.0659 (0.0786)  loss_objectness: 0.0039 (0.0061)  loss_rpn_box_reg: 0.0078 (0.0093)  time: 2.5439  data: 0.0271  max mem: 11382
# Epoch: [1]  [520/751]  eta: 0:09:47  lr: 0.002000  loss: 0.1552 (0.1875)  loss_classifier: 0.0720 (0.0935)  loss_box_reg: 0.0668 (0.0787)  loss_objectness: 0.0040 (0.0061)  loss_rpn_box_reg: 0.0065 (0.0093)  time: 2.5506  data: 0.0271  max mem: 11382
# Epoch: [1]  [530/751]  eta: 0:09:22  lr: 0.002000  loss: 0.1592 (0.1877)  loss_classifier: 0.0863 (0.0936)  loss_box_reg: 0.0729 (0.0787)  loss_objectness: 0.0057 (0.0061)  loss_rpn_box_reg: 0.0054 (0.0093)  time: 2.5526  data: 0.0274  max mem: 11382
# Epoch: [1]  [540/751]  eta: 0:08:56  lr: 0.002000  loss: 0.1592 (0.1876)  loss_classifier: 0.0863 (0.0936)  loss_box_reg: 0.0659 (0.0786)  loss_objectness: 0.0057 (0.0062)  loss_rpn_box_reg: 0.0063 (0.0093)  time: 2.5447  data: 0.0280  max mem: 11382
# Epoch: [1]  [550/751]  eta: 0:08:31  lr: 0.002000  loss: 0.1752 (0.1879)  loss_classifier: 0.0815 (0.0935)  loss_box_reg: 0.0715 (0.0788)  loss_objectness: 0.0059 (0.0063)  loss_rpn_box_reg: 0.0066 (0.0093)  time: 2.5298  data: 0.0286  max mem: 11382
# Epoch: [1]  [560/751]  eta: 0:08:05  lr: 0.002000  loss: 0.1572 (0.1871)  loss_classifier: 0.0731 (0.0931)  loss_box_reg: 0.0689 (0.0786)  loss_objectness: 0.0045 (0.0062)  loss_rpn_box_reg: 0.0052 (0.0093)  time: 2.5277  data: 0.0281  max mem: 11382
# Epoch: [1]  [570/751]  eta: 0:07:40  lr: 0.002000  loss: 0.1542 (0.1870)  loss_classifier: 0.0757 (0.0930)  loss_box_reg: 0.0698 (0.0786)  loss_objectness: 0.0045 (0.0062)  loss_rpn_box_reg: 0.0052 (0.0092)  time: 2.5448  data: 0.0266  max mem: 11382
# Epoch: [1]  [580/751]  eta: 0:07:14  lr: 0.002000  loss: 0.1617 (0.1869)  loss_classifier: 0.0770 (0.0929)  loss_box_reg: 0.0729 (0.0785)  loss_objectness: 0.0053 (0.0062)  loss_rpn_box_reg: 0.0077 (0.0092)  time: 2.5517  data: 0.0263  max mem: 11382
# Epoch: [1]  [590/751]  eta: 0:06:49  lr: 0.002000  loss: 0.1801 (0.1869)  loss_classifier: 0.0825 (0.0929)  loss_box_reg: 0.0744 (0.0786)  loss_objectness: 0.0039 (0.0062)  loss_rpn_box_reg: 0.0080 (0.0093)  time: 2.5489  data: 0.0264  max mem: 11382
# Epoch: [1]  [600/751]  eta: 0:06:23  lr: 0.002000  loss: 0.1441 (0.1862)  loss_classifier: 0.0716 (0.0925)  loss_box_reg: 0.0650 (0.0783)  loss_objectness: 0.0039 (0.0062)  loss_rpn_box_reg: 0.0080 (0.0093)  time: 2.5386  data: 0.0268  max mem: 11382
# Epoch: [1]  [610/751]  eta: 0:05:58  lr: 0.002000  loss: 0.1441 (0.1862)  loss_classifier: 0.0692 (0.0924)  loss_box_reg: 0.0625 (0.0784)  loss_objectness: 0.0040 (0.0061)  loss_rpn_box_reg: 0.0056 (0.0092)  time: 2.5352  data: 0.0264  max mem: 11382
# Epoch: [1]  [620/751]  eta: 0:05:33  lr: 0.002000  loss: 0.1503 (0.1855)  loss_classifier: 0.0691 (0.0920)  loss_box_reg: 0.0636 (0.0782)  loss_objectness: 0.0041 (0.0061)  loss_rpn_box_reg: 0.0067 (0.0092)  time: 2.5472  data: 0.0269  max mem: 11382
# Epoch: [1]  [630/751]  eta: 0:05:07  lr: 0.002000  loss: 0.1543 (0.1851)  loss_classifier: 0.0674 (0.0917)  loss_box_reg: 0.0665 (0.0781)  loss_objectness: 0.0042 (0.0061)  loss_rpn_box_reg: 0.0059 (0.0092)  time: 2.5485  data: 0.0270  max mem: 11382
# Epoch: [1]  [640/751]  eta: 0:04:42  lr: 0.002000  loss: 0.1683 (0.1855)  loss_classifier: 0.0711 (0.0918)  loss_box_reg: 0.0795 (0.0784)  loss_objectness: 0.0048 (0.0062)  loss_rpn_box_reg: 0.0080 (0.0092)  time: 2.5349  data: 0.0265  max mem: 11382
# Epoch: [1]  [650/751]  eta: 0:04:16  lr: 0.002000  loss: 0.1872 (0.1855)  loss_classifier: 0.0878 (0.0917)  loss_box_reg: 0.0828 (0.0784)  loss_objectness: 0.0060 (0.0062)  loss_rpn_box_reg: 0.0079 (0.0092)  time: 2.5390  data: 0.0268  max mem: 11382
# Epoch: [1]  [660/751]  eta: 0:03:51  lr: 0.002000  loss: 0.1525 (0.1849)  loss_classifier: 0.0780 (0.0913)  loss_box_reg: 0.0727 (0.0783)  loss_objectness: 0.0053 (0.0061)  loss_rpn_box_reg: 0.0054 (0.0092)  time: 2.5475  data: 0.0260  max mem: 11382
# Epoch: [1]  [670/751]  eta: 0:03:25  lr: 0.002000  loss: 0.1389 (0.1845)  loss_classifier: 0.0627 (0.0911)  loss_box_reg: 0.0635 (0.0782)  loss_objectness: 0.0036 (0.0061)  loss_rpn_box_reg: 0.0062 (0.0091)  time: 2.5466  data: 0.0260  max mem: 11382
# Epoch: [1]  [680/751]  eta: 0:03:00  lr: 0.002000  loss: 0.1487 (0.1844)  loss_classifier: 0.0732 (0.0910)  loss_box_reg: 0.0631 (0.0781)  loss_objectness: 0.0039 (0.0061)  loss_rpn_box_reg: 0.0072 (0.0091)  time: 2.5469  data: 0.0265  max mem: 11382
# Epoch: [1]  [690/751]  eta: 0:02:35  lr: 0.002000  loss: 0.1567 (0.1841)  loss_classifier: 0.0704 (0.0909)  loss_box_reg: 0.0698 (0.0780)  loss_objectness: 0.0047 (0.0061)  loss_rpn_box_reg: 0.0066 (0.0091)  time: 2.5476  data: 0.0273  max mem: 11382
# Epoch: [1]  [700/751]  eta: 0:02:09  lr: 0.002000  loss: 0.1568 (0.1845)  loss_classifier: 0.0787 (0.0911)  loss_box_reg: 0.0803 (0.0782)  loss_objectness: 0.0038 (0.0061)  loss_rpn_box_reg: 0.0053 (0.0091)  time: 2.5466  data: 0.0271  max mem: 11382
# Epoch: [1]  [710/751]  eta: 0:01:44  lr: 0.002000  loss: 0.1744 (0.1841)  loss_classifier: 0.0787 (0.0910)  loss_box_reg: 0.0736 (0.0780)  loss_objectness: 0.0039 (0.0061)  loss_rpn_box_reg: 0.0055 (0.0091)  time: 2.5488  data: 0.0263  max mem: 11382
# Epoch: [1]  [720/751]  eta: 0:01:18  lr: 0.002000  loss: 0.1296 (0.1836)  loss_classifier: 0.0656 (0.0906)  loss_box_reg: 0.0562 (0.0778)  loss_objectness: 0.0046 (0.0061)  loss_rpn_box_reg: 0.0061 (0.0091)  time: 2.5485  data: 0.0260  max mem: 11382
# Epoch: [1]  [730/751]  eta: 0:00:53  lr: 0.002000  loss: 0.1634 (0.1838)  loss_classifier: 0.0768 (0.0908)  loss_box_reg: 0.0715 (0.0780)  loss_objectness: 0.0040 (0.0060)  loss_rpn_box_reg: 0.0072 (0.0091)  time: 2.5436  data: 0.0262  max mem: 11382
# Epoch: [1]  [740/751]  eta: 0:00:27  lr: 0.002000  loss: 0.1800 (0.1836)  loss_classifier: 0.0786 (0.0906)  loss_box_reg: 0.0792 (0.0779)  loss_objectness: 0.0036 (0.0060)  loss_rpn_box_reg: 0.0072 (0.0091)  time: 2.5399  data: 0.0263  max mem: 11382
# Epoch: [1]  [750/751]  eta: 0:00:02  lr: 0.002000  loss: 0.1647 (0.1834)  loss_classifier: 0.0743 (0.0905)  loss_box_reg: 0.0710 (0.0778)  loss_objectness: 0.0040 (0.0061)  loss_rpn_box_reg: 0.0074 (0.0090)  time: 2.5348  data: 0.0257  max mem: 11382
# Epoch: [1] Total time: 0:31:50 (2.5437 s / it)
# creating index...
# index created!
# Test:  [  0/108]  eta: 0:02:28  model_time: 1.1037 (1.1037)  evaluator_time: 0.0106 (0.0106)  time: 1.3735  data: 0.2538  max mem: 11382
# Test:  [100/108]  eta: 0:00:09  model_time: 1.0852 (1.0790)  evaluator_time: 0.0131 (0.0164)  time: 1.1151  data: 0.0247  max mem: 11382
# Test:  [107/108]  eta: 0:00:01  model_time: 0.9920 (1.0714)  evaluator_time: 0.0125 (0.0161)  time: 1.0685  data: 0.0246  max mem: 11382
# Test: Total time: 0:02:01 (1.1220 s / it)
# Averaged stats: model_time: 0.9920 (1.0714)  evaluator_time: 0.0125 (0.0161)
# Accumulating evaluation results...
# DONE (t=0.58s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.154
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.304
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.137
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.087
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.170
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.156
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.237
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.334
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.343
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.247
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.359
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.339
# Epoch: [2]  [  0/751]  eta: 0:35:37  lr: 0.002000  loss: 0.1633 (0.1633)  loss_classifier: 0.0722 (0.0722)  loss_box_reg: 0.0779 (0.0779)  loss_objectness: 0.0048 (0.0048)  loss_rpn_box_reg: 0.0085 (0.0085)  time: 2.8466  data: 0.3072  max mem: 11382
# Epoch: [2]  [ 10/751]  eta: 0:31:47  lr: 0.002000  loss: 0.1417 (0.1358)  loss_classifier: 0.0537 (0.0585)  loss_box_reg: 0.0605 (0.0646)  loss_objectness: 0.0048 (0.0052)  loss_rpn_box_reg: 0.0062 (0.0075)  time: 2.5739  data: 0.0496  max mem: 11382
# Epoch: [2]  [ 20/751]  eta: 0:31:12  lr: 0.002000  loss: 0.1417 (0.1406)  loss_classifier: 0.0537 (0.0640)  loss_box_reg: 0.0639 (0.0657)  loss_objectness: 0.0038 (0.0044)  loss_rpn_box_reg: 0.0053 (0.0065)  time: 2.5473  data: 0.0254  max mem: 11382
# Epoch: [2]  [ 30/751]  eta: 0:30:44  lr: 0.002000  loss: 0.1518 (0.1470)  loss_classifier: 0.0671 (0.0674)  loss_box_reg: 0.0669 (0.0685)  loss_objectness: 0.0025 (0.0041)  loss_rpn_box_reg: 0.0049 (0.0070)  time: 2.5494  data: 0.0272  max mem: 11382
# Epoch: [2]  [ 40/751]  eta: 0:30:14  lr: 0.002000  loss: 0.1348 (0.1436)  loss_classifier: 0.0648 (0.0664)  loss_box_reg: 0.0639 (0.0656)  loss_objectness: 0.0033 (0.0043)  loss_rpn_box_reg: 0.0050 (0.0073)  time: 2.5418  data: 0.0266  max mem: 11382
# Epoch: [2]  [ 50/751]  eta: 0:29:46  lr: 0.002000  loss: 0.1340 (0.1430)  loss_classifier: 0.0618 (0.0666)  loss_box_reg: 0.0602 (0.0655)  loss_objectness: 0.0029 (0.0040)  loss_rpn_box_reg: 0.0050 (0.0069)  time: 2.5343  data: 0.0259  max mem: 11382
# Epoch: [2]  [ 60/751]  eta: 0:29:19  lr: 0.002000  loss: 0.1362 (0.1463)  loss_classifier: 0.0621 (0.0681)  loss_box_reg: 0.0676 (0.0667)  loss_objectness: 0.0031 (0.0041)  loss_rpn_box_reg: 0.0055 (0.0073)  time: 2.5350  data: 0.0262  max mem: 11382
# Epoch: [2]  [ 70/751]  eta: 0:28:54  lr: 0.002000  loss: 0.1365 (0.1480)  loss_classifier: 0.0652 (0.0694)  loss_box_reg: 0.0656 (0.0666)  loss_objectness: 0.0033 (0.0046)  loss_rpn_box_reg: 0.0069 (0.0074)  time: 2.5403  data: 0.0259  max mem: 11382
# Epoch: [2]  [ 80/751]  eta: 0:28:28  lr: 0.002000  loss: 0.1279 (0.1455)  loss_classifier: 0.0610 (0.0678)  loss_box_reg: 0.0568 (0.0658)  loss_objectness: 0.0033 (0.0045)  loss_rpn_box_reg: 0.0066 (0.0074)  time: 2.5458  data: 0.0255  max mem: 11382
# Epoch: [2]  [ 90/751]  eta: 0:28:02  lr: 0.002000  loss: 0.1430 (0.1478)  loss_classifier: 0.0630 (0.0690)  loss_box_reg: 0.0653 (0.0669)  loss_objectness: 0.0029 (0.0044)  loss_rpn_box_reg: 0.0069 (0.0075)  time: 2.5437  data: 0.0258  max mem: 11382
# Epoch: [2]  [100/751]  eta: 0:27:36  lr: 0.002000  loss: 0.1536 (0.1486)  loss_classifier: 0.0705 (0.0693)  loss_box_reg: 0.0662 (0.0673)  loss_objectness: 0.0034 (0.0044)  loss_rpn_box_reg: 0.0066 (0.0076)  time: 2.5400  data: 0.0266  max mem: 11382
# Epoch: [2]  [110/751]  eta: 0:27:11  lr: 0.002000  loss: 0.1237 (0.1485)  loss_classifier: 0.0556 (0.0692)  loss_box_reg: 0.0635 (0.0674)  loss_objectness: 0.0034 (0.0043)  loss_rpn_box_reg: 0.0060 (0.0076)  time: 2.5387  data: 0.0272  max mem: 11382
# Epoch: [2]  [120/751]  eta: 0:26:46  lr: 0.002000  loss: 0.1242 (0.1462)  loss_classifier: 0.0524 (0.0679)  loss_box_reg: 0.0635 (0.0665)  loss_objectness: 0.0030 (0.0043)  loss_rpn_box_reg: 0.0059 (0.0075)  time: 2.5495  data: 0.0270  max mem: 11382
# Epoch: [2]  [130/751]  eta: 0:26:20  lr: 0.002000  loss: 0.1394 (0.1467)  loss_classifier: 0.0558 (0.0680)  loss_box_reg: 0.0596 (0.0669)  loss_objectness: 0.0030 (0.0042)  loss_rpn_box_reg: 0.0065 (0.0076)  time: 2.5445  data: 0.0265  max mem: 11382
# Epoch: [2]  [140/751]  eta: 0:25:54  lr: 0.002000  loss: 0.1395 (0.1470)  loss_classifier: 0.0569 (0.0682)  loss_box_reg: 0.0707 (0.0672)  loss_objectness: 0.0031 (0.0042)  loss_rpn_box_reg: 0.0056 (0.0074)  time: 2.5336  data: 0.0262  max mem: 11382
# Epoch: [2]  [150/751]  eta: 0:25:29  lr: 0.002000  loss: 0.1504 (0.1481)  loss_classifier: 0.0624 (0.0682)  loss_box_reg: 0.0691 (0.0679)  loss_objectness: 0.0028 (0.0044)  loss_rpn_box_reg: 0.0054 (0.0076)  time: 2.5415  data: 0.0262  max mem: 11382
# Epoch: [2]  [160/751]  eta: 0:25:03  lr: 0.002000  loss: 0.1443 (0.1486)  loss_classifier: 0.0629 (0.0689)  loss_box_reg: 0.0627 (0.0678)  loss_objectness: 0.0019 (0.0043)  loss_rpn_box_reg: 0.0054 (0.0075)  time: 2.5464  data: 0.0263  max mem: 11382
# Epoch: [2]  [170/751]  eta: 0:24:38  lr: 0.002000  loss: 0.1339 (0.1481)  loss_classifier: 0.0630 (0.0685)  loss_box_reg: 0.0626 (0.0679)  loss_objectness: 0.0027 (0.0043)  loss_rpn_box_reg: 0.0051 (0.0075)  time: 2.5524  data: 0.0269  max mem: 11382
# Epoch: [2]  [180/751]  eta: 0:24:13  lr: 0.002000  loss: 0.1339 (0.1481)  loss_classifier: 0.0620 (0.0683)  loss_box_reg: 0.0707 (0.0680)  loss_objectness: 0.0034 (0.0044)  loss_rpn_box_reg: 0.0044 (0.0074)  time: 2.5491  data: 0.0274  max mem: 11382
# Epoch: [2]  [190/751]  eta: 0:23:47  lr: 0.002000  loss: 0.1302 (0.1482)  loss_classifier: 0.0619 (0.0684)  loss_box_reg: 0.0707 (0.0681)  loss_objectness: 0.0031 (0.0044)  loss_rpn_box_reg: 0.0047 (0.0073)  time: 2.5389  data: 0.0268  max mem: 11382
# Epoch: [2]  [200/751]  eta: 0:23:21  lr: 0.002000  loss: 0.1480 (0.1496)  loss_classifier: 0.0669 (0.0691)  loss_box_reg: 0.0664 (0.0687)  loss_objectness: 0.0041 (0.0045)  loss_rpn_box_reg: 0.0049 (0.0073)  time: 2.5397  data: 0.0265  max mem: 11382
# Epoch: [2]  [210/751]  eta: 0:22:56  lr: 0.002000  loss: 0.1465 (0.1492)  loss_classifier: 0.0669 (0.0689)  loss_box_reg: 0.0688 (0.0685)  loss_objectness: 0.0046 (0.0046)  loss_rpn_box_reg: 0.0060 (0.0073)  time: 2.5395  data: 0.0265  max mem: 11382
# Epoch: [2]  [220/751]  eta: 0:22:30  lr: 0.002000  loss: 0.1260 (0.1490)  loss_classifier: 0.0628 (0.0688)  loss_box_reg: 0.0642 (0.0685)  loss_objectness: 0.0034 (0.0046)  loss_rpn_box_reg: 0.0050 (0.0072)  time: 2.5380  data: 0.0263  max mem: 11382
# Epoch: [2]  [230/751]  eta: 0:22:05  lr: 0.002000  loss: 0.1188 (0.1483)  loss_classifier: 0.0628 (0.0687)  loss_box_reg: 0.0537 (0.0680)  loss_objectness: 0.0028 (0.0045)  loss_rpn_box_reg: 0.0047 (0.0071)  time: 2.5411  data: 0.0270  max mem: 11382
# Epoch: [2]  [240/751]  eta: 0:21:40  lr: 0.002000  loss: 0.1270 (0.1474)  loss_classifier: 0.0602 (0.0684)  loss_box_reg: 0.0501 (0.0675)  loss_objectness: 0.0020 (0.0045)  loss_rpn_box_reg: 0.0048 (0.0071)  time: 2.5481  data: 0.0276  max mem: 11382
# Epoch: [2]  [250/751]  eta: 0:21:14  lr: 0.002000  loss: 0.1391 (0.1476)  loss_classifier: 0.0629 (0.0684)  loss_box_reg: 0.0604 (0.0676)  loss_objectness: 0.0038 (0.0045)  loss_rpn_box_reg: 0.0073 (0.0072)  time: 2.5498  data: 0.0268  max mem: 11382
# Epoch: [2]  [260/751]  eta: 0:20:49  lr: 0.002000  loss: 0.1450 (0.1482)  loss_classifier: 0.0638 (0.0685)  loss_box_reg: 0.0657 (0.0680)  loss_objectness: 0.0041 (0.0045)  loss_rpn_box_reg: 0.0073 (0.0071)  time: 2.5459  data: 0.0260  max mem: 11382
# ...
# Epoch: [3]  [190/751]  eta: 0:23:44  lr: 0.000200  loss: 0.1132 (0.1199)  loss_classifier: 0.0464 (0.0506)  loss_box_reg: 0.0542 (0.0587)  loss_objectness: 0.0025 (0.0034)  loss_rpn_box_reg: 0.0054 (0.0072)  time: 2.5416  data: 0.0266  max mem: 11382
# Epoch: [3]  [200/751]  eta: 0:23:18  lr: 0.000200  loss: 0.1093 (0.1191)  loss_classifier: 0.0451 (0.0504)  loss_box_reg: 0.0520 (0.0582)  loss_objectness: 0.0026 (0.0034)  loss_rpn_box_reg: 0.0048 (0.0071)  time: 2.5361  data: 0.0263  max mem: 11382
# Epoch: [3]  [210/751]  eta: 0:22:53  lr: 0.000200  loss: 0.0905 (0.1176)  loss_classifier: 0.0370 (0.0496)  loss_box_reg: 0.0412 (0.0575)  loss_objectness: 0.0028 (0.0034)  loss_rpn_box_reg: 0.0061 (0.0071)  time: 2.5375  data: 0.0263  max mem: 11382
# Epoch: [3]  [220/751]  eta: 0:22:28  lr: 0.000200  loss: 0.0887 (0.1169)  loss_classifier: 0.0357 (0.0493)  loss_box_reg: 0.0391 (0.0572)  loss_objectness: 0.0024 (0.0034)  loss_rpn_box_reg: 0.0062 (0.0071)  time: 2.5437  data: 0.0261  max mem: 11382
# Epoch: [3]  [230/751]  eta: 0:22:03  lr: 0.000200  loss: 0.0954 (0.1163)  loss_classifier: 0.0373 (0.0489)  loss_box_reg: 0.0494 (0.0569)  loss_objectness: 0.0024 (0.0034)  loss_rpn_box_reg: 0.0055 (0.0071)  time: 2.5441  data: 0.0257  max mem: 11382
# Epoch: [3]  [240/751]  eta: 0:21:37  lr: 0.000200  loss: 0.0954 (0.1161)  loss_classifier: 0.0348 (0.0488)  loss_box_reg: 0.0506 (0.0568)  loss_objectness: 0.0021 (0.0034)  loss_rpn_box_reg: 0.0052 (0.0071)  time: 2.5395  data: 0.0258  max mem: 11382
# Epoch: [3]  [250/751]  eta: 0:21:12  lr: 0.000200  loss: 0.0943 (0.1156)  loss_classifier: 0.0348 (0.0484)  loss_box_reg: 0.0540 (0.0567)  loss_objectness: 0.0024 (0.0034)  loss_rpn_box_reg: 0.0060 (0.0072)  time: 2.5362  data: 0.0265  max mem: 11382
# Epoch: [3]  [260/751]  eta: 0:20:46  lr: 0.000200  loss: 0.1102 (0.1164)  loss_classifier: 0.0446 (0.0487)  loss_box_reg: 0.0563 (0.0571)  loss_objectness: 0.0028 (0.0035)  loss_rpn_box_reg: 0.0060 (0.0071)  time: 2.5359  data: 0.0272  max mem: 11382
# Epoch: [3]  [270/751]  eta: 0:20:21  lr: 0.000200  loss: 0.1108 (0.1168)  loss_classifier: 0.0471 (0.0488)  loss_box_reg: 0.0637 (0.0573)  loss_objectness: 0.0019 (0.0035)  loss_rpn_box_reg: 0.0056 (0.0071)  time: 2.5367  data: 0.0276  max mem: 11382
# Epoch: [3]  [280/751]  eta: 0:19:55  lr: 0.000200  loss: 0.1110 (0.1164)  loss_classifier: 0.0443 (0.0486)  loss_box_reg: 0.0518 (0.0572)  loss_objectness: 0.0016 (0.0035)  loss_rpn_box_reg: 0.0050 (0.0071)  time: 2.5348  data: 0.0268  max mem: 11382
# Epoch: [3]  [290/751]  eta: 0:19:30  lr: 0.000200  loss: 0.1116 (0.1166)  loss_classifier: 0.0443 (0.0487)  loss_box_reg: 0.0539 (0.0573)  loss_objectness: 0.0024 (0.0035)  loss_rpn_box_reg: 0.0046 (0.0070)  time: 2.5369  data: 0.0268  max mem: 11382
# Epoch: [3]  [300/751]  eta: 0:19:05  lr: 0.000200  loss: 0.1213 (0.1174)  loss_classifier: 0.0456 (0.0492)  loss_box_reg: 0.0575 (0.0576)  loss_objectness: 0.0037 (0.0035)  loss_rpn_box_reg: 0.0047 (0.0071)  time: 2.5396  data: 0.0268  max mem: 11382
# Epoch: [3]  [310/751]  eta: 0:18:39  lr: 0.000200  loss: 0.1167 (0.1175)  loss_classifier: 0.0456 (0.0491)  loss_box_reg: 0.0565 (0.0578)  loss_objectness: 0.0037 (0.0036)  loss_rpn_box_reg: 0.0066 (0.0071)  time: 2.5309  data: 0.0269  max mem: 11382
# Epoch: [3]  [320/751]  eta: 0:18:14  lr: 0.000200  loss: 0.1203 (0.1180)  loss_classifier: 0.0479 (0.0493)  loss_box_reg: 0.0565 (0.0580)  loss_objectness: 0.0026 (0.0036)  loss_rpn_box_reg: 0.0064 (0.0072)  time: 2.5299  data: 0.0272  max mem: 11382
# Epoch: [3]  [330/751]  eta: 0:17:48  lr: 0.000200  loss: 0.1096 (0.1177)  loss_classifier: 0.0479 (0.0492)  loss_box_reg: 0.0533 (0.0579)  loss_objectness: 0.0026 (0.0035)  loss_rpn_box_reg: 0.0049 (0.0072)  time: 2.5405  data: 0.0269  max mem: 11382
# Epoch: [3]  [340/751]  eta: 0:17:23  lr: 0.000200  loss: 0.0961 (0.1173)  loss_classifier: 0.0377 (0.0489)  loss_box_reg: 0.0503 (0.0577)  loss_objectness: 0.0027 (0.0035)  loss_rpn_box_reg: 0.0050 (0.0072)  time: 2.5434  data: 0.0267  max mem: 11382
# Epoch: [3]  [350/751]  eta: 0:16:57  lr: 0.000200  loss: 0.0961 (0.1165)  loss_classifier: 0.0370 (0.0486)  loss_box_reg: 0.0434 (0.0572)  loss_objectness: 0.0027 (0.0035)  loss_rpn_box_reg: 0.0067 (0.0072)  time: 2.5416  data: 0.0266  max mem: 11382
# Epoch: [3]  [360/751]  eta: 0:16:32  lr: 0.000200  loss: 0.0966 (0.1166)  loss_classifier: 0.0377 (0.0487)  loss_box_reg: 0.0444 (0.0572)  loss_objectness: 0.0032 (0.0035)  loss_rpn_box_reg: 0.0078 (0.0073)  time: 2.5361  data: 0.0264  max mem: 11382
# Epoch: [3]  [370/751]  eta: 0:16:07  lr: 0.000200  loss: 0.1263 (0.1167)  loss_classifier: 0.0454 (0.0487)  loss_box_reg: 0.0617 (0.0573)  loss_objectness: 0.0030 (0.0035)  loss_rpn_box_reg: 0.0050 (0.0072)  time: 2.5406  data: 0.0267  max mem: 11382
# Epoch: [3]  [380/751]  eta: 0:15:41  lr: 0.000200  loss: 0.1158 (0.1167)  loss_classifier: 0.0502 (0.0488)  loss_box_reg: 0.0573 (0.0573)  loss_objectness: 0.0024 (0.0035)  loss_rpn_box_reg: 0.0037 (0.0072)  time: 2.5419  data: 0.0268  max mem: 11382
# Epoch: [3]  [390/751]  eta: 0:15:16  lr: 0.000200  loss: 0.1015 (0.1166)  loss_classifier: 0.0434 (0.0487)  loss_box_reg: 0.0476 (0.0573)  loss_objectness: 0.0018 (0.0034)  loss_rpn_box_reg: 0.0068 (0.0072)  time: 2.5344  data: 0.0265  max mem: 11382
# Epoch: [3]  [400/751]  eta: 0:14:51  lr: 0.000200  loss: 0.1051 (0.1168)  loss_classifier: 0.0450 (0.0487)  loss_box_reg: 0.0524 (0.0575)  loss_objectness: 0.0021 (0.0034)  loss_rpn_box_reg: 0.0068 (0.0072)  time: 2.5386  data: 0.0269  max mem: 11382
# Epoch: [3]  [410/751]  eta: 0:14:25  lr: 0.000200  loss: 0.1001 (0.1163)  loss_classifier: 0.0422 (0.0485)  loss_box_reg: 0.0516 (0.0572)  loss_objectness: 0.0034 (0.0035)  loss_rpn_box_reg: 0.0054 (0.0072)  time: 2.5451  data: 0.0268  max mem: 11382
# Epoch: [3]  [420/751]  eta: 0:14:00  lr: 0.000200  loss: 0.0915 (0.1158)  loss_classifier: 0.0385 (0.0483)  loss_box_reg: 0.0413 (0.0569)  loss_objectness: 0.0030 (0.0035)  loss_rpn_box_reg: 0.0052 (0.0072)  time: 2.5467  data: 0.0265  max mem: 11382
# Epoch: [3]  [430/751]  eta: 0:13:35  lr: 0.000200  loss: 0.0955 (0.1157)  loss_classifier: 0.0412 (0.0482)  loss_box_reg: 0.0473 (0.0569)  loss_objectness: 0.0025 (0.0035)  loss_rpn_box_reg: 0.0048 (0.0071)  time: 2.5460  data: 0.0264  max mem: 11382
# Epoch: [3]  [440/751]  eta: 0:13:09  lr: 0.000200  loss: 0.0963 (0.1156)  loss_classifier: 0.0444 (0.0481)  loss_box_reg: 0.0498 (0.0568)  loss_objectness: 0.0028 (0.0035)  loss_rpn_box_reg: 0.0052 (0.0071)  time: 2.5459  data: 0.0272  max mem: 11382
# Epoch: [3]  [450/751]  eta: 0:12:44  lr: 0.000200  loss: 0.0968 (0.1150)  loss_classifier: 0.0364 (0.0479)  loss_box_reg: 0.0476 (0.0565)  loss_objectness: 0.0028 (0.0035)  loss_rpn_box_reg: 0.0049 (0.0071)  time: 2.5448  data: 0.0275  max mem: 11382
# Epoch: [3]  [460/751]  eta: 0:12:18  lr: 0.000200  loss: 0.0968 (0.1151)  loss_classifier: 0.0394 (0.0479)  loss_box_reg: 0.0492 (0.0565)  loss_objectness: 0.0032 (0.0035)  loss_rpn_box_reg: 0.0061 (0.0071)  time: 2.5410  data: 0.0268  max mem: 11382
# Epoch: [3]  [470/751]  eta: 0:11:53  lr: 0.000200  loss: 0.1040 (0.1149)  loss_classifier: 0.0443 (0.0478)  loss_box_reg: 0.0520 (0.0565)  loss_objectness: 0.0032 (0.0035)  loss_rpn_box_reg: 0.0060 (0.0071)  time: 2.5451  data: 0.0266  max mem: 11382
# Epoch: [3]  [480/751]  eta: 0:11:28  lr: 0.000200  loss: 0.0935 (0.1147)  loss_classifier: 0.0375 (0.0477)  loss_box_reg: 0.0506 (0.0564)  loss_objectness: 0.0021 (0.0035)  loss_rpn_box_reg: 0.0049 (0.0072)  time: 2.5477  data: 0.0269  max mem: 11382
# Epoch: [3]  [490/751]  eta: 0:11:02  lr: 0.000200  loss: 0.0935 (0.1145)  loss_classifier: 0.0375 (0.0476)  loss_box_reg: 0.0456 (0.0562)  loss_objectness: 0.0027 (0.0035)  loss_rpn_box_reg: 0.0059 (0.0072)  time: 2.5473  data: 0.0269  max mem: 11382
# Epoch: [3]  [500/751]  eta: 0:10:37  lr: 0.000200  loss: 0.1053 (0.1144)  loss_classifier: 0.0401 (0.0476)  loss_box_reg: 0.0542 (0.0562)  loss_objectness: 0.0027 (0.0035)  loss_rpn_box_reg: 0.0056 (0.0072)  time: 2.5483  data: 0.0277  max mem: 11382
# Epoch: [3]  [510/751]  eta: 0:10:12  lr: 0.000200  loss: 0.0988 (0.1142)  loss_classifier: 0.0395 (0.0475)  loss_box_reg: 0.0491 (0.0560)  loss_objectness: 0.0017 (0.0035)  loss_rpn_box_reg: 0.0056 (0.0072)  time: 2.5447  data: 0.0281  max mem: 11382
# Epoch: [3]  [520/751]  eta: 0:09:46  lr: 0.000200  loss: 0.0809 (0.1137)  loss_classifier: 0.0349 (0.0473)  loss_box_reg: 0.0408 (0.0557)  loss_objectness: 0.0024 (0.0034)  loss_rpn_box_reg: 0.0052 (0.0072)  time: 2.5410  data: 0.0271  max mem: 11382
# Epoch: [3]  [530/751]  eta: 0:09:21  lr: 0.000200  loss: 0.0830 (0.1132)  loss_classifier: 0.0333 (0.0470)  loss_box_reg: 0.0414 (0.0555)  loss_objectness: 0.0027 (0.0034)  loss_rpn_box_reg: 0.0050 (0.0072)  time: 2.5384  data: 0.0269  max mem: 11382
# Epoch: [3]  [540/751]  eta: 0:08:55  lr: 0.000200  loss: 0.0912 (0.1131)  loss_classifier: 0.0344 (0.0470)  loss_box_reg: 0.0478 (0.0555)  loss_objectness: 0.0024 (0.0034)  loss_rpn_box_reg: 0.0041 (0.0072)  time: 2.5359  data: 0.0268  max mem: 11382
# Epoch: [3]  [550/751]  eta: 0:08:30  lr: 0.000200  loss: 0.1090 (0.1136)  loss_classifier: 0.0427 (0.0473)  loss_box_reg: 0.0518 (0.0557)  loss_objectness: 0.0018 (0.0034)  loss_rpn_box_reg: 0.0046 (0.0072)  time: 2.5393  data: 0.0262  max mem: 11382
# Epoch: [3]  [560/751]  eta: 0:08:05  lr: 0.000200  loss: 0.1124 (0.1137)  loss_classifier: 0.0567 (0.0474)  loss_box_reg: 0.0503 (0.0557)  loss_objectness: 0.0027 (0.0034)  loss_rpn_box_reg: 0.0052 (0.0072)  time: 2.5421  data: 0.0262  max mem: 11382
# Epoch: [3]  [570/751]  eta: 0:07:39  lr: 0.000200  loss: 0.1178 (0.1138)  loss_classifier: 0.0498 (0.0474)  loss_box_reg: 0.0535 (0.0558)  loss_objectness: 0.0027 (0.0034)  loss_rpn_box_reg: 0.0063 (0.0072)  time: 2.5460  data: 0.0271  max mem: 11382
# Epoch: [3]  [580/751]  eta: 0:07:14  lr: 0.000200  loss: 0.1049 (0.1137)  loss_classifier: 0.0422 (0.0474)  loss_box_reg: 0.0532 (0.0558)  loss_objectness: 0.0018 (0.0034)  loss_rpn_box_reg: 0.0058 (0.0072)  time: 2.5505  data: 0.0272  max mem: 11382
# Epoch: [3]  [590/751]  eta: 0:06:49  lr: 0.000200  loss: 0.0954 (0.1135)  loss_classifier: 0.0369 (0.0472)  loss_box_reg: 0.0494 (0.0557)  loss_objectness: 0.0021 (0.0034)  loss_rpn_box_reg: 0.0041 (0.0072)  time: 2.5478  data: 0.0264  max mem: 11382
# Epoch: [3]  [600/751]  eta: 0:06:23  lr: 0.000200  loss: 0.0982 (0.1132)  loss_classifier: 0.0403 (0.0472)  loss_box_reg: 0.0491 (0.0555)  loss_objectness: 0.0023 (0.0034)  loss_rpn_box_reg: 0.0047 (0.0072)  time: 2.5430  data: 0.0260  max mem: 11382
# Epoch: [3]  [610/751]  eta: 0:05:58  lr: 0.000200  loss: 0.1038 (0.1133)  loss_classifier: 0.0439 (0.0472)  loss_box_reg: 0.0505 (0.0556)  loss_objectness: 0.0026 (0.0034)  loss_rpn_box_reg: 0.0048 (0.0072)  time: 2.5426  data: 0.0270  max mem: 11382
# Epoch: [3]  [620/751]  eta: 0:05:32  lr: 0.000200  loss: 0.1067 (0.1131)  loss_classifier: 0.0442 (0.0472)  loss_box_reg: 0.0521 (0.0555)  loss_objectness: 0.0036 (0.0034)  loss_rpn_box_reg: 0.0046 (0.0071)  time: 2.5440  data: 0.0275  max mem: 11382
# Epoch: [3]  [630/751]  eta: 0:05:07  lr: 0.000200  loss: 0.1108 (0.1131)  loss_classifier: 0.0430 (0.0471)  loss_box_reg: 0.0542 (0.0555)  loss_objectness: 0.0031 (0.0034)  loss_rpn_box_reg: 0.0046 (0.0071)  time: 2.5451  data: 0.0272  max mem: 11382
# Epoch: [3]  [640/751]  eta: 0:04:42  lr: 0.000200  loss: 0.1061 (0.1130)  loss_classifier: 0.0385 (0.0471)  loss_box_reg: 0.0589 (0.0555)  loss_objectness: 0.0019 (0.0034)  loss_rpn_box_reg: 0.0049 (0.0071)  time: 2.5534  data: 0.0281  max mem: 11382
# Epoch: [3]  [650/751]  eta: 0:04:16  lr: 0.000200  loss: 0.0964 (0.1127)  loss_classifier: 0.0402 (0.0469)  loss_box_reg: 0.0504 (0.0553)  loss_objectness: 0.0023 (0.0034)  loss_rpn_box_reg: 0.0049 (0.0071)  time: 2.5320  data: 0.0275  max mem: 11382
# Epoch: [3]  [660/751]  eta: 0:03:51  lr: 0.000200  loss: 0.0922 (0.1128)  loss_classifier: 0.0390 (0.0470)  loss_box_reg: 0.0468 (0.0554)  loss_objectness: 0.0023 (0.0034)  loss_rpn_box_reg: 0.0052 (0.0071)  time: 2.5218  data: 0.0267  max mem: 11382
# Epoch: [3]  [670/751]  eta: 0:03:25  lr: 0.000200  loss: 0.0877 (0.1127)  loss_classifier: 0.0348 (0.0469)  loss_box_reg: 0.0454 (0.0553)  loss_objectness: 0.0019 (0.0034)  loss_rpn_box_reg: 0.0051 (0.0070)  time: 2.5405  data: 0.0264  max mem: 11382
# Epoch: [3]  [680/751]  eta: 0:03:00  lr: 0.000200  loss: 0.0926 (0.1129)  loss_classifier: 0.0348 (0.0471)  loss_box_reg: 0.0475 (0.0555)  loss_objectness: 0.0019 (0.0033)  loss_rpn_box_reg: 0.0050 (0.0070)  time: 2.5419  data: 0.0265  max mem: 11382
# Epoch: [3]  [690/751]  eta: 0:02:34  lr: 0.000200  loss: 0.0963 (0.1127)  loss_classifier: 0.0372 (0.0469)  loss_box_reg: 0.0475 (0.0555)  loss_objectness: 0.0018 (0.0033)  loss_rpn_box_reg: 0.0047 (0.0070)  time: 2.5415  data: 0.0268  max mem: 11382
# Epoch: [3]  [700/751]  eta: 0:02:09  lr: 0.000200  loss: 0.0793 (0.1123)  loss_classifier: 0.0306 (0.0467)  loss_box_reg: 0.0427 (0.0553)  loss_objectness: 0.0017 (0.0033)  loss_rpn_box_reg: 0.0051 (0.0070)  time: 2.5449  data: 0.0268  max mem: 11382
# Epoch: [3]  [710/751]  eta: 0:01:44  lr: 0.000200  loss: 0.0895 (0.1123)  loss_classifier: 0.0336 (0.0467)  loss_box_reg: 0.0445 (0.0553)  loss_objectness: 0.0017 (0.0033)  loss_rpn_box_reg: 0.0055 (0.0070)  time: 2.5434  data: 0.0267  max mem: 11382
# Epoch: [3]  [720/751]  eta: 0:01:18  lr: 0.000200  loss: 0.1045 (0.1123)  loss_classifier: 0.0385 (0.0467)  loss_box_reg: 0.0560 (0.0554)  loss_objectness: 0.0017 (0.0033)  loss_rpn_box_reg: 0.0053 (0.0069)  time: 2.5335  data: 0.0269  max mem: 11382
# Epoch: [3]  [730/751]  eta: 0:00:53  lr: 0.000200  loss: 0.0971 (0.1119)  loss_classifier: 0.0376 (0.0465)  loss_box_reg: 0.0509 (0.0552)  loss_objectness: 0.0017 (0.0033)  loss_rpn_box_reg: 0.0046 (0.0069)  time: 2.5378  data: 0.0267  max mem: 11382
# Epoch: [3]  [740/751]  eta: 0:00:27  lr: 0.000200  loss: 0.1088 (0.1121)  loss_classifier: 0.0473 (0.0466)  loss_box_reg: 0.0454 (0.0552)  loss_objectness: 0.0028 (0.0033)  loss_rpn_box_reg: 0.0049 (0.0069)  time: 2.5463  data: 0.0259  max mem: 11382
# Epoch: [3]  [750/751]  eta: 0:00:02  lr: 0.000200  loss: 0.1124 (0.1120)  loss_classifier: 0.0491 (0.0466)  loss_box_reg: 0.0485 (0.0552)  loss_objectness: 0.0033 (0.0033)  loss_rpn_box_reg: 0.0049 (0.0069)  time: 2.5363  data: 0.0263  max mem: 11382
# Epoch: [3] Total time: 0:31:48 (2.5410 s / it)
# creating index...
# index created!
# Test:  [  0/108]  eta: 0:02:27  model_time: 1.0800 (1.0800)  evaluator_time: 0.0084 (0.0084)  time: 1.3657  data: 0.2718  max mem: 11382
# Test:  [100/108]  eta: 0:00:08  model_time: 1.0832 (1.0743)  evaluator_time: 0.0098 (0.0118)  time: 1.1032  data: 0.0253  max mem: 11382
# Test:  [107/108]  eta: 0:00:01  model_time: 0.9801 (1.0660)  evaluator_time: 0.0091 (0.0116)  time: 1.0550  data: 0.0251  max mem: 11382
# Test: Total time: 0:02:00 (1.1117 s / it)
# Averaged stats: model_time: 0.9801 (1.0660)  evaluator_time: 0.0091 (0.0116)
# Accumulating evaluation results...
# DONE (t=0.38s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.219
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.397
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.220
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.132
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.249
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.206
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.280
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.363
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.369
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.260
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.360

# %% [markdown]
# ##**Running Inference**

# %%
os.mkdir("/content/drive/MyDrive/fasterRCNN_results")
torch.save(model.state_dict(), "/content/drive/MyDrive/fasterRCNN_results/model")

# %%
loaded_model = get_model(num_classes = 16)
loaded_model.load_state_dict(torch.load('/content/drive/MyDrive/fasterRCNN_results/model', map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
labels=[ 'rov',
 'plant',
 'animal_fish',
 'animal_starfish',
 'animal_shells',
 'animal_crab',
 'animal_eel',
 'animal_etc',
 'trash_etc',
 'trash_fabric',
 'trash_fishing_gear',
 'trash_metal',
 'trash_paper',
 'trash_plastic',
 'trash_rubber',
 'trash_wood']

# %%
with open('/content/drive/MyDrive/UTD_val.pkl', "rb") as fh:
  test_df = pickle.load(fh)
  #test_df.fillna("nan")
files = ['vid_000077_frame0000020.jpg', 'vid_000090_frame0000051.jpg', 'vid_000106_frame0000027.jpg']
i = 0

for im_file in files:
  temp = test_df[test_df.file_name == im_file]
  idx = temp.image_id.values[0]
  
  #labels = list(temp.category_id.values)
  
  img, _ = val[idx]
  label_boxes = np.array(val[idx][1]["boxes"])

  loaded_model.eval()
  with torch.no_grad():
    prediction = loaded_model([img])
  image = Image.fromarray(img.mul(255).permute(1, 2,0).byte().numpy())
  draw = ImageDraw.Draw(image)

  # draw groundtruth
  for elem in range(len(label_boxes)):
    draw.rectangle([(label_boxes[elem][0], label_boxes[elem][1]),
    (label_boxes[elem][2], label_boxes[elem][3])], 
    outline ="green", width =3)

  # draw predictions
  for element in range(len(prediction[0]["boxes"])):
    boxes = prediction[0]["boxes"][element].cpu().numpy()
    score = np.round(prediction[0]["scores"][element].cpu().numpy(), decimals= 4)
    if score > 0.5:
        draw.rectangle([(boxes[0], boxes[1]), (boxes[2], boxes[3])], 
        outline ="yellow", width =3)
        draw.text((boxes[0], boxes[1]), text = str(score))
        #draw.text((boxes[0], boxes[1]), text = str(labels[element]))
  plt.figure(i,figsize=(15,15))
  plt.imshow(image)
  i += 1
